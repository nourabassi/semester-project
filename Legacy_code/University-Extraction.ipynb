# %%
import re
import pandas as pd
import os
import sys
import json
import numpy as np
# %matplotlib inline
USER_ENV = '/Users/lguillain/Documents/EPFL2018/Git-semester-project/data/' 
rootdir = USER_ENV + 'papers/'

# %%
contents = []
i = 0
source = []
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        source.append(file[:-4])
        if 'txt' in file:
            #print(subdir[len(rootdir):])
            i += 1
            path = os.path.join(subdir, file)
            with open(path) as file:
                #print(subdir)
                #print(text.read())
                try:
                    text = file.read()
                    contents.append(text)
                except:
                    #Will fails for some files in python 3 .. still trying to find the issue
                    name, message, content = sys.exc_info()
                    print(message)

# %% [markdown]
# Using python 3:

# %%
contents[0]
# Out:
# 'Learning Scientific Practices Through Participation as a Volunteer\nCommunity Scientist\nRebecca D. Swanson, Leighanna Hinojosa, and Joseph L. Polman\nrebecca.swanson@colorado.edu, leighanna.hinojosa@colorado.edu, joseph.polman@colorado.edu\nUniversity of Colorado Boulder\n\nAbstract: An ethnographic study of community scientist volunteers in a museum-embedded\ngenetics lab clarifies how participants are afforded or constrained in opportunities to learn\nscientific practices through an apprenticeship-model program. Guided participation in the lab\nresults in participatory appropriation of scientific practices by volunteers. Community\nscientists enter as newcomers, then gain experience through opportunities to observe and\nengage in a range of scientific practices associated with studies on genetics of taste and\neveryday lab support tasks.\nKeywords: community science, citizen science, apprenticeship learning, informal learning\n\nIntroduction\n\nOver the last two decades, there has been an increased focus on the participation of members of the general\npublic in aspects of scientific research, commonly referred to as citizen science. These types of volunteer\nprograms, also referred to as Public Participation in Scientific Research (PPSR, Shirk et al., 2012) or\n“community science,” generally provide opportunities for volunteers to contribute to various aspects of\nscientific research. While the availability of volunteers to collect data is of clear benefit to science researchers,\nthere is an ongoing question as to the benefit of such participation to the volunteers themselves. Too often,\nvolunteers can be relegated to the role of “databots” guided in collecting rigorous data following protocols,\nwithout an understanding of the scientific issues that render it meaningful (Pea, et al., 1997). What benefit do\nthe community scientists themselves derive from their participation in such practices and others designed into\ncommunity science programs? We examine one program in detail to answer the question: How do individuals\nvolunteering as community scientists in a museum-embedded genetics lab learn scientific practices through their\nparticipation in ongoing studies of the genetics of taste?\n\nTheoretical framework\n\nWe draw on Rogoff’s (1995) framework of learning through participation on three planes of sociocultural\nactivity: apprenticeship, guided participation, and participatory appropriation. The broadest plane is the\ncommunity level of activity, which Rogoff refers to as apprenticeship, as newcomers to the community learn\nnew skills through first-hand participation (Lave & Wenger, 1991). The next plane of activity focuses on the\ninterpersonal level of participation – guided participation – which describes how multiple individuals interact\nwithin the context of the mutual activity. The final plane of activity narrows the focus to an individual’s process\nof learning new tasks and using new skills to participate in activities in more knowledgeable ways. Rogoff refers\nto this plane as participatory appropriation. Community scientists are positioned as novices within the\ncommunity, embedded within existing institutional systems that proscribe engagement in the activity, with tasks\ndirected by more experienced individuals. In this way, we identify learning as a change in participation in\npractices, looking for evidence of learning within and through the three planes of analysis.\n\nMethods\n\nThis study took place inside a genetics lab embedded within an exhibit on the human body in a large natural\nhistory museum in the Western U. S. The work of the community scientists who volunteer in this lab is directed\non a day-to-day basis by a lab manager and three museum staff members. The community scientists in the lab\nare responsible for daily maintenance tasks related to the exhibit-associated experiment area as well as enrolling\nmuseum guests in ongoing genetics studies and other study-related tasks.\nWe took  ...

# %%
schools = open(USER_ENV+'/world_universities_and_domains.json').read()
parsed_json = json.loads(schools)

# %% [markdown]
# Number of schools in json

# %%
len(parsed_json)
# Out:
# 9682

# %% [markdown]
# #### Rational for using email vs extracting institution from text:
# - easier to parse from text
# - unique / more robust to spelling changes

# %% [markdown]
# at most howmany domains are there per school?

# %%
max([len(j['domains']) for j in parsed_json])
# Out:
# 3

# %%
mapping = {}
country_uni = {}
for j in parsed_json:
    mapping[j['domains'][0]] = j['name']
    country_uni[j['domains'][0]] = j['country']
    if len(j['domains']) > 1:
        mapping[j['domains'][1]] = j['name']
        country_uni[j['domains'][1]] = j['country']
    if len(j['domains']) > 2:
        mapping[j['domains'][2]] = j['name']
        country_uni[j['domains'][2]] = j['country']

# %%
mapping
# Out:
# {'cstj.qc.ca': 'Cégep de Saint-Jérôme',
#  'lindenwood.edu': 'Lindenwood University',
#  'davietjal.org': 'DAV Institute of Engineering & Technology',
#  'lpu.in': 'Lovely Professional University',
#  'sullivan.edu': 'Sullivan University',
#  'fscj.edu': 'Florida State College at Jacksonville',
#  'xavier.edu': 'Xavier University',
#  'tusculum.edu': 'Tusculum College',
#  'cst.edu': 'Claremont School of Theology',
#  'somaiya.edu': 'Somaiya Vidyavihar',
#  'columbiasc.edu': 'Columbia College (SC)',
#  'clpccd.edu': 'Chabot-Las Positas Community College District',
#  'keller.edu': 'Keller Graduate School of Management',
#  'monroecollege.edu': 'Monroe College',
#  'smccd.edu': 'San Mateo County Community College District',
#  'losrios.edu': 'Los Rios Community College District',
#  'digipen.edu': 'DigiPen Institute of Technology',
#  'upmc.edu': 'University of Pittsburgh Medical Center',
#  'upmc.com': 'University of Pittsburgh Medical Center',
#  'cgu.edu': 'Claremont Graduate University',
#  'utrgv.edu': 'University of Texas Rio Grande Valley',
#  'mountsaintvincent.edu': 'College of Mount Saint Vincent',
#  'uasys.edu': 'University of Arkansas System eVersity',
#  'ecpi.edu': 'ECPI University',
#  'umw.edu': 'University of Mary Washington',
#  'bw.edu': 'Baldwin Wallace University',
#  'csuci.edu': 'California State University Channel Islands',
#  'brandman.edu': 'Brandman University',
#  'uscga.edu': 'United States Coast Guard Academy',
#  'athens.edu': 'Athens State University',
#  'scripps.edu': 'The Scripps Research Institute',
#  'easternflorida.edu': 'Eastern Florida State College',
#  'wne.edu': 'Western New England University',
#  'king.edu': 'King University',
#  'ggc.edu': 'Georgia Gwinnett College',
#  'trident.edu': 'Trident University',
#  'alliant.edu': 'Alliant International University',
#  'mvsu.edu': 'Mississippi Valley State University',
#  'roosevelt.edu': 'Roosevelt University',
#  'itt-tech.info': 'ITT Technical Institute',
#  'itt-tech.edu': 'ITT Technical Institute',
#  'iecc.edu': 'Illinois Eastern Community Colleges',
#  'park.edu': 'Park University',
#  'mssm.edu': 'Icahn School of Medicine at Mount Sinai',
#  'uvu.edu': 'Utah Valley Uniersity',
#  'wlc.edu': 'Wisconsin Lutheran College',
#  'rccd.edu': 'Riverside Community College District',
#  'wakehealth.edu': 'Wake Forest Baptist Health',
#  'umb.edu': 'University of Massachusetts Boston',
#  'floridapoly.edu': 'Florida Polytechnic University',
#  'wagner.edu': 'Wagner College',
#  'wilmu.edu': 'Wilmington University',
#  'itu.edu': 'International Technological University',
#  'yhc.edu': 'Young Harris College',
#  'findlay.edu': 'University of Findlay',
#  'pcom.edu': 'Philadelphia College of Osteopathic Medicine',
#  'yosemite.edu': 'Yosemite Community College District',
#  'coastalalabama.edu': 'Coastal Alabama Community College',
#  'pnw.edu': 'Purdue University Northwest',
#  'columbiabasin.edu': 'Columbia Basin College',
#  'seattlecolleges.edu': 'Seattle Colleges',
#  'lipscomb.edu': 'Lipscomb University',
#  'tiffin.edu': 'Tiffin University',
#  'ncuindia.edu': 'NorthCap University',
#  'troy.edu': 'Troy University',
#  'student.42.us.org': '42 US',
#  'calbaptist.edu': 'California Baptist University',
#  'stevenson.edu': 'Stevenson University',
#  'mbl.edu': 'Marine Biological Laboratory',
#  'maryville.edu': 'Maryville University',
#  'aii.edu': 'The Art Institutes',
#  'umc.edu': 'University of Mississippi Medical Center',
#  'uco.edu': 'University of Central Oklahoma',
#  'hallmarkuniversity.edu': 'Hallmark University',
#  'keiseruniversity.edu': 'Keiser University',
#  'sjrstate.edu': 'St. Johns River State College',
#  'irsc.edu': 'Indian River State College',
#  'barnard.edu': 'Barnard College',
#  'tesu.edu': 'Thomas Edison State University',
#  'calsouthern.edu': 'California Southern University',
#  'laverne.edu': 'University of La Verne',
#  'washjeff.edu': 'Washington &amp; Jefferson College',
#  'uopeople.edu': 'University of the People',
#  'touro.edu': 'Touro College',
#  'njcu.edu': 'New Jersey City University',
#  'lander.edu': 'Lander University',
#  'sunymaritime.edu': 'SUNY Maritime College',
#  'lesley.edu': 'Lesley University',
#  'lauruscollege.edu': 'Laurus College',
#  'np.edu': 'National Park College',
#  'oc.edu': 'Oklahoma Christian University',
#  'sdcc.edu': 'San Diego Christian College',
#  'sans.edu': 'SANS Technology Institute',
#  'phsc.edu': 'Pasco-Hernando State College',
#  'ncf.edu': 'New College of Florida',
#  'gcu.edu': 'Grand Canyon University',
#  'cshl.edu': 'Cold Spring Harbor Laboratory',
#  'asurams.edu': 'Albany State University',
#  'lasell.edu': 'Lasell College',
#  '4cd.edu': 'Contra Costa Community College District',
#  'msmary.edu': "Mount St. Mary's University",
#  'robertmorris.edu': 'Robert Morris University Illinois',
#  'nwfsc.edu': 'Northwest Florida State College',
#  'wvwc.edu': 'West Virginia Wesleyan College',
#  'utica.edu': 'Utica College',
#  'ccnn.edu': 'Career College of Northern Nevada',
#  'ung.edu': 'University of North Georgia',
#  'principia.edu': 'The Principia',
#  'lynn.edu': 'Lynn University',
#  'cccs.edu': 'Colorado Community College System',
#  'valenciacollege.edu': 'Valencia College',
#  'spcollege.edu': 'St. Petersburg College',
#  'msbcollege.edu': 'Globe University &amp; Minnesota School of Business',
#  'everest.edu': 'Everest College',
#  'swri.edu': 'Southwest Research Institute',
#  'apus.edu': 'American Public University System',
#  'fullsail.edu': 'Full Sail University',
#  'yti.edu': 'YTI Career Institute',
#  'dliflc.edu': 'Defense Language Institute Foreign Language Center',
#  'columbusstate.edu': 'Columbus State University',
#  'moreheadstate.edu': 'Morehead State University',
#  'csuglobal.edu': 'Colorado State University - Global Campus',
#  'ndus.edu': 'North Dakota University System',
#  'uhd.edu': 'University of Houston-Downtown',
#  'stratford.edu': 'Stratford University',
#  'cpp.edu': 'California Polytechnic State University, Pomona',
#  'baker.edu': 'Baker College',
#  'tcnj.edu': 'The College of New Jersey',
#  'acu.edu': 'Abilene Christian University',
#  'adelphi.edu': 'Adelphi University',
#  'agnesscott.edu': 'Agnes Scott College',
#  'atc.edu': 'Aiken Technical College',
#  'afit.af.mil': 'Air Force Institute of Technology',
#  'afit.edu': 'Air Force Institute of Technology',
#  'aamu.edu': 'Alabama A&M University',
#  'alasu.edu': 'Alabama State University',
#  'aloma.edu': 'Alamo Colleges',
#  'acofi.edu': 'Albertson College of Idaho',
#  'albion.edu': 'Albion College',
#  'alfred.edu': 'Alfred University',
#  'alleg.edu': 'Allegheny College',
#  'allencol.edu': 'Allentown College of Saint Francis de Sales',
#  'alma.edu': 'Alma College',
#  'alverno.edu': 'Alverno College',
#  'ambassador.edu': 'Ambassador University',
#  'amercoastuniv.edu': 'American Coastline University',
#  'aic.edu': 'American International College',
#  'american.edu': 'American University',
#  'amherst.edu': 'Amherst College',
#  'andrews.edu': 'Andrews University',
#  'angelo.edu': 'Angelo State University',
#  'aacc.edu': 'Anne Arundel Community College',
#  'antiochne.edu': 'Antioch New England',
#  'antioch.edu': 'Antioch University',
#  'antiochla.edu': 'Antioch University - Los Angeles',
#  'seattleantioch.edu': 'Antioch University - Seattle',
#  'appstate.edu': 'Appalachian State University',
#  'aquinas.edu': 'Aquinas College',
#  'arcadia.edu': 'Arcadia College',
#  'asu.edu': 'Arizona State University',
#  'azwestern.edu': 'Arizona Western College',
#  'astate.edu': 'Arkansas State University',
#  'atu.edu': 'Arkansas Tech University',
#  'armstrong.edu': 'Armstrong State College',
#  'ashland.edu': 'Ashland University',
#  'assumption.edu': 'Assumption College',
#  'auburn.edu': 'Auburn University',
#  'aum.edu': 'Auburn University at Montgomery',
#  'augsburg.edu': 'Augsburg College',
#  'augustana.edu': 'Augustana College (IL)',
#  'augie.edu': 'Augustana College (SD)',
#  'augusta.edu': 'Augusta University',
#  'gru.edu': 'Augusta University',
#  'aurora.edu': 'Aurora University',
#  'austincollege.edu': 'Austin College',
#  'austincc.edu': 'Austin Community College',
#  'apsu.edu': 'Austin Peay State University',
#  'averett.edu': 'Averett College',
#  'avila.edu': 'Avila College',
#  'apu.edu': 'Azusa Pacific University',
#  'babson.edu': 'Babson College',
#  'bakeru.edu': 'Baker University',
#  'bsu.edu': 'Ball State University',
#  'bbc.edu': 'Baptist Bible College',
#  'bard.edu': 'Bard College',
#  'barry.edu': 'Barry University',
#  'bastyr.edu': 'Bastyr University',
#  'bates.edu': 'Bates College',
#  'bcm.edu': 'Baylor College of Medicine',
#  'baylor.edu': 'Baylor University',
#  'bellevue.edu': 'Bellevue University',
#  'belmont.edu': 'Belmont University',
#  'beloit.edu': 'Beloit College',
#  'bemidjistate.edu': 'Bemidji State University',
#  'benedictine.edu': 'Benedictine College',
#  'bennington.edu': 'Bennington College',
#  'bentley.edu': 'Bentley College',
#  'berea.edu': 'Berea College',
#  'berklee.edu': 'Berklee College of Music',
#  'bethanywv.edu': 'Bethany College',
#  'bethelks.edu': 'Bethel College (KS)',
#  'bethel.edu': 'Bethel University',
#  'biola.edu': 'Biola University',
#  'bsc.edu': 'Birmingham-Southern College',
#  'bhsu.edu': 'Black Hills State University',
#  'bloomu.edu': 'Bloomsburg University of Pennsylvania',
#  'bluffton.edu': 'Bluffton College',
#  'bju.edu': 'Bob Jones University',
#  'idbsu.edu': 'Boise State University',
#  'boisestate.edu': 'Boise State University',
#  'bc.edu': 'Boston College',
#  'bgsp.edu': 'Boston Graduate School of Psychoanalysis',
#  'bu.edu': 'Boston University',
#  'bowdoin.edu': 'Bowdoin College',
#  'bowiestate.edu': 'Bowie State University',
#  'bgsu.edu': 'Bowling Green State University',
#  'bradley.edu': 'Bradley University',
#  'brandeis.edu': 'Brandeis University',
#  'brenau.edu': 'Brenau University',
#  'briar-cliff.edu': 'Briar Cliff College',
#  'bridgewater.edu': 'Bridgewater College',
#  'byu.edu': 'Brigham Young University',
#  'byui.edu': 'Brigham Young University - Idaho',
#  'byuh.edu': 'Brigham Young University Hawaii',
#  'broward.edu': 'Broward College',
#  'brown.edu': 'Brown University',
#  'bryant.edu': 'Bryant College',
#  'brynmawr.edu': 'Bryn Mawr College',
#  'bucknell.edu': 'Bucknell University',
#  'bvu.edu': 'Buena Vista University',
#  'butler.edu': 'Butler University',
#  'calcoast.edu': 'California Coast University',
#  'caltech.edu': 'California Institute of Technology',
#  'callutheran.edu': 'California Lutheran University',
#  'csum.edu': 'California Maritime Academy',
#  'cnuas.edu': 'California National University',
#  'calpoly.edu': 'California Polytechnic State University, San Luis Obispo',
#  'csub.edu': 'California State University, Bakersfield',
#  'csubak.edu': 'California State University, Bakersfield',
#  'csuchico.edu': 'California State University, Chico',
#  'csudh.edu': 'California State University, Dominguez Hills',
#  'csufresno.edu': 'California State University, Fresno',
#  'fresnostate.edu': 'California State University, Fresno',
#  'fullerton.edu': 'California State University, Fullerton',
#  'csuhayward.edu': 'California State University, Hayward',
#  'csulb.edu': 'California State University, Long Beach',
#  'calstatela.edu': 'California State University, Los Angeles',
#  'monterey.edu': 'California State University, Monterey Bay',
#  'csun.edu': 'California State University, Northridge',
#  'csus.edu': 'California State University, Sacramento',
#  'csusb.edu': 'California State University, San Bernardino',
#  'sjsu.edu': 'San Jose State University',
#  'csusm.edu': 'California State University, San Marcos',
#  'csustan.edu': 'California State University, Stanislaus',
#  'calstate.edu': 'California State University System',
#  'cup.edu': 'California University of Pennsylvania',
#  'calvin.edu': 'Calvin College',
#  'cameron.edu': 'Cameron University',
#  'campbellsville.edu': 'Campbellsville College',
#  'campbell.edu': 'Campbell University',
#  'canisius.edu': 'Canisius College',
#  'capella.edu': 'Capella University',
#  'capellauniversity.edu': 'Capella University',
#  'captechu.edu': 'Capitol Technology University',
#  'carleton.edu': 'Carleton College',
#  'carlow.edu': 'Carlow College',
#  'cmu.edu': 'Carnegie Mellon University',
#  'carroll.edu': 'Carroll College',
#  'carrollu.edu': 'Carroll University',
#  'cn.edu': 'Carson-Newman College',
#  'carthage.edu': 'Carthage College',
#  'case.edu': 'Case Western Reserve University',
#  'castleton.edu': 'Castleton State University',
#  'cua.edu': 'Catholic University of America',
#  'cedarville.edu': 'Cedarville College',
#  'centenary.edu': 'Centenary College of Louisiana',
#  'central.edu': 'Central College',
#  'ccsu.edu': 'Central Connecticut State University',
#  'cmc.edu': 'Central Methodist College',
#  'cmich.edu': 'Central Michigan University',
#  'cwu.edu': 'Central Washington University',
#  'centre.edu': 'Centre College',
#  'csc.edu': 'Chadron State College',
#  'champlain.edu': 'Champlain College',
#  'chapman.edu': 'Chapman University',
#  'chatham.edu': 'Chatham College',
#  'chesapeake.edu': 'Chesapeake College',
#  'cheyney.edu': 'Cheyney University',
#  'csopp.edu': 'Chicago School of Professional Psychology',
#  'cbu.edu': 'Christian Brothers University',
#  'cts.edu': 'Christian Theological Seminary',
#  'cnu.edu': 'Christopher Newport University',
#  'cityu.edu': 'City University',
#  'cityuniversity.edu': 'City University',
#  'cuny.edu': 'City University of New York',
#  'cgs.edu': 'Claremont Graduate School',
#  'mckenna.edu': 'Claremont McKenna College',
#  'clarion.edu': 'Clarion University of Pennsylvania',
#  'clarke.edu': 'Clarke College',
#  'clarkson.edu': 'Clarkson University',
#  'clarku.edu': 'Clark University',
#  'clayton.edu': 'Clayton State College',
#  'clemson.edu': 'Clemson University',
#  'csuohio.edu': 'Cleveland State University',
#  'clinch.edu': 'Clinch Valley College',
#  'coastal.edu': 'Coastal Carolina University',
#  'cccd.edu': 'Coast Colleges',
#  'coe.edu': 'Coe College',
#  'coker.edu': 'Coker College',
#  'colby.edu': 'Colby College',
#  'colgate.edu': 'Colgate University',
#  'cofc.edu': 'College of Charleston',
#  'ceu.edu': 'College of Eastern Utah',
#  'cnr.edu': 'College of New Rochelle',
#  'csbsju.edu': "Saint John's University (MN)",
#  'stkate.edu': 'College of Saint Catherine',
#  'strose.edu': 'College of Saint Rose',
#  'stfrancis.edu': 'College of St. Francis',
#  'css.edu': 'College of St. Scholastica',
#  'coa.edu': 'College of the Atlantic',
#  'holycross.edu': 'College of the Holy Cross',
#  'wm.edu': 'College of William and Mary',
#  'wooster.edu': 'College of Wooster',
#  'ccu.edu': 'Colorado Christian University',
#  'coloradocollege.edu': 'Colorado College',
#  'coloradomesa.edu': 'Colorado Mesa University',
#  'mines.edu': 'Colorado School of Mines',
#  'colostate.edu': 'Colorado State University',
#  'coloradotech.edu': 'Colorado Technical University',
#  'ctuonline.edu': 'Colorado Technical University',
#  'colum.edu': 'Columbia College Chicago',
#  'colsouth.edu': 'Columbia Southern University',
#  'cuc.edu': 'Columbia Union College',
#  'columbia.edu': 'Columbia University',
#  'ccbcmd.edu': 'Community College of Baltimore County',
#  'ccaa.edu': 'Concordia College - Ann Arbor',
#  'cord.edu': 'Concordia College - Moorhead',
#  'ccsn.edu': 'Concordia College - Seward',
#  'csp.edu': 'Concordia College - St. Paul',
#  'conncoll.edu': 'Connecticut College',
#  'ct.edu': 'Connecticut State University System',
#  'cooper.edu': 'Cooper Union for the Advancement of Science and Art',
#  'coppin.edu': 'Coppin State University',
#  'cornell-iowa.edu': 'Cornell College',
#  'cornell.edu': 'Cornell University',
#  'corning-cc.edu': 'Corning Community College',
#  'creighton.edu': 'Creighton University',
#  'curry.edu': 'Curry College',
#  'daemen.edu': 'Daemen College',
#  'dsu.edu': 'Dakota State University',
#  'dwu.edu': 'Dakota Wesleyan University',
#  'dbu.edu': 'Dallas Baptist University',
#  'dcccd.edu': 'Dallas County Community College',
#  'dana.edu': 'Dana College',
#  'dwc.edu': 'Daniel Webster College',
#  'dartmouth.edu': 'Dartmouth College',
#  'davenport.edu': 'Davenport University',
#  'davidson.edu': 'Davidson College',
#  'dne.wvnet.edu': 'Davis & Elkins College',
#  'daytonastate.edu': 'Daytona State College',
#  'dsc.edu': 'Delaware State University',
#  'deltastate.edu': 'Delta State University',
#  'denison.edu': 'Denison University',
#  'depaul.edu': 'DePaul University',
#  'depauw.edu': 'DePauw University',
#  'devry.edu': 'DeVry Institute of Technology',
#  'ddu.ac.in': 'Dharamsinh Desai University',
#  'dickinson.edu': 'Dickinson College',
#  'dickinsonstate.edu': 'Dickinson State University',
#  'dillard.edu': 'Dillard University',
#  'dominican.edu': 'Dominican College',
#  'dordt.edu': 'Dordt College',
#  'dowling.edu': 'Dowling College',
#  'drake.edu': 'Drake University',
#  'drew.edu': 'Drew University',
#  'drexel.edu': 'Drexel University',
#  'drury.edu': 'Drury College',
#  'duke.edu': 'Duke University',
#  'duq.edu': 'Duquesne University',
#  'earlham.edu': 'Earlham College',
#  'ecu.edu': 'East Carolina University',
#  'ecok.edu': 'East Central University',
#  'easternct.edu': 'Eastern Connecticut State University',
#  'eiu.edu': 'Eastern Illinois University',
#  'eku.edu': 'Eastern Kentucky University',
#  'emu.edu': 'Eastern Mennonite University',
#  'emich.edu': 'Eastern Michigan University',
#  'enmu.edu': 'Eastern New Mexico University',
#  'eou.edu': 'Eastern Oregon State College',
#  'ewu.edu': 'Eastern Washington University',
#  'esu.edu': 'East Stroudsburg State University of Pennsylvania',
#  'etsu.edu': 'East Tennessee State University',
#  'edgewood.edu': 'Edgewood College',
#  'edinboro.edu': 'Edinboro University of Pennsylvania',
#  'ecsu.edu': 'Elizabeth City State University',
#  'etown.edu': 'Elizabethtown College',
#  'elmhurst.edu': 'Elmhurst College',
#  'elon.edu': 'Elon College',
#  'erau.edu': 'Embry-Riddle Aeronautical University',
#  'emerson.edu': 'Emerson College',
#  'emmanuel.edu': 'Emmanuel College',
#  'emory.edu': 'Emory University',
#  'emporia.edu': 'Emporia State University',
#  'ecc.edu': 'Erie Community College',
#  'evergreen.edu': 'Evergreen State College',
#  'fdu.edu': 'Fairleigh Dickinson University',
#  'fairmontstate.edu': 'Fairmont State College',
#  'uncfsu.edu': 'Fayetteville State University',
#  'ferris.edu': 'Ferris State University',
#  'fielding.edu': 'Fielding Institute',
#  'fisk.edu': 'Fisk University',
#  'fsc.edu': 'Fitchburg State College',
#  'famu.edu': 'Florida Agricultural and Mechanical University',
#  'fau.edu': 'Florida Atlantic University',
#  'fgcu.edu': 'Florida Gulf Coast University',
#  'fit.edu': 'Florida Institute of Technology',
#  'fiu.edu': 'Florida International University',
#  'fsu.edu': 'Florida State University',
#  'fontbonne.edu': 'Fontbonne College',
#  'fordham.edu': 'Fordham University',
#  'fhsu.edu': 'Fort Hays State University',
#  'fortlewis.edu': 'Fort Lewis College',
#  'fountainheadcollege.edu': 'Fountainhead College of Technology',
#  'fandm.edu': 'Franklin and Marshall College',
#  'fplc.edu': 'Franklin Pierce Law Center',
#  'franklin.edu': 'Franklin University',
#  'frederick.edu': 'Frederick Community College',
#  'fresno.edu': 'Fresno Pacific University',
#  'friends.edu': 'Friends University',
#  'frostburg.edu': 'Frostburg State University',
#  'fuller.edu': 'Fuller Theological Seminary',
#  'furman.edu': 'Furman University',
#  'gallaudet.edu': 'Gallaudet University',
#  'gannon.edu': 'Gannon University',
#  'geneva.edu': 'Geneva College',
#  'gfc.edu': 'George Fox College',
#  'gmu.edu': 'George Mason University',
#  'georgetown.edu': 'Georgetown University',
#  'gwu.edu': 'George Washington University',
#  'gcsu.edu': 'Georgia College',
#  'gatech.edu': 'Georgia Institute of Technology',
#  'georgian.edu': 'Georgian Court College',
#  'georgiasouthern.edu': 'Georgia Southern University',
#  'gsw.edu': 'Georgia Southwestern State University',
#  'gsu.edu': 'Georgia State University',
#  'gettysburg.edu': 'Gettysburg College',
#  'gmi.edu': 'GMI Engineering and Management Institute',
#  'ggu.edu': 'Golden Gate University',
#  'gbc.edu': 'Goldey-Beacom College',
#  'gonzaga.edu': 'Gonzaga University',
#  'goshen.edu': 'Goshen College',
#  'goucher.edu': 'Goucher College',
#  'govst.edu': 'Governors State University',
#  'grace.edu': 'Grace College',
#  'graceland.edu': 'Graceland College',
#  'gvsu.edu': 'Grand Valley State University',
#  'greenleaf.edu': 'Greenleaf University',
#  'grinnell.edu': 'Grinnell College',
#  'guilford.edu': 'Guilford College',
#  'gac.edu': 'Gustavus Adolphus College',
#  'hagerstowncc.edu': 'Hagerstown Community College',
#  'hamilton.edu': 'Hamilton College',
#  'hamline.edu': 'Hamline University',
#  'hsc.edu': 'Hampden-Sydney College',
#  'hampshire.edu': 'Hampshire College',
#  'hamptonu.edu': 'Hampton University',
#  'hanover.edu': 'Hanover College',
#  'harding.edu': 'Harding University',
#  'harford.edu': 'Harford Community College',
#  'hartwick.edu': 'Hartwick College',
#  'harvard.edu': 'Harvard University',
#  'hmc.edu': 'Harvey Mudd College',
#  'haskell.edu': 'Haskell Indian Nations University',
#  'hastings.edu': 'Hastings College',
#  'haverford.edu': 'Haverford College in Pennsylvania',
#  'hpu.edu': 'Hawaii Pacific University',
#  'heidelberg.edu': 'Heidelberg College',
#  'hendrix.edu': 'Hendrix College',
#  'hesston.edu': 'Hesston College',
#  'highpoint.edu': 'High Point University',
#  'hillsdale.edu': 'Hillsdale College',
#  'hiram.edu': 'Hiram College',
#  'hws.edu': 'Hobart and William Smith Colleges',
#  'hofstra.edu': 'Hofstra University',
#  'hollins.edu': 'Hollins College',
#  'hood.edu': 'Hood College',
#  'hope.edu': 'Hope College',
#  'howardcc.edu': 'Howard Community College',
#  'howard.edu': 'Howard University',
#  'humboldt.edu': 'Humboldt State University',
#  'hunter.cuny.edu': 'Hunter College',
#  'huntingdon.edu': 'Huntingdon College',
#  'huntington.edu': 'Huntington University',
#  'ici.edu': 'ICI University',
#  'isu.edu': 'Idaho State University',
#  'ibc.edu': 'Illinois Benedictine College',
#  'iit.edu': 'Illinois Institute of Technology',
#  'illinoisstate.edu': 'Illinois State University',
#  'ilstu.edu': 'Illinois State University',
#  'indianatech.edu': 'Indiana Institute of Technology',
#  'indianatech.net': 'Indiana Institute of Technology',
#  'indstate.edu': 'Indiana State University',
#  'iu.edu': 'Indiana University',
#  'indiana.edu': 'Indiana University at Bloomington',
#  'iub.edu': 'Indiana University at Bloomington',
#  'iusb.edu': 'Indiana University at South Bend',
#  'iup.edu': 'Indiana University of Pennsylvania',
#  'iupuc.edu': 'Indiana University/Purdue University at Columbus',
#  'ipfw.edu': 'Indiana University/Purdue University at Fort Wayne',
#  'iupui.edu': 'Indiana University/Purdue University at Indianapolis',
#  'ius.edu': 'Indiana University Southeast',
#  'indwes.edu': 'Indiana Wesleyan University, Marion',
#  'iwp.edu': 'Institute for World Politics',
#  'iona.edu': 'Iona College',
#  'iastate.edu': 'Iowa State University',
#  'ivc.edu': 'Irvine Valley College',
#  'ithaca.edu': 'Ithaca College',
#  'jsums.edu': 'Jackson State University',
#  'jsu.edu': 'Jacksonville State University',
#  'ju.edu': 'Jacksonville University',
#  'jmu.edu': 'James Madison University',
#  'jbu.edu': 'John Brown University',
#  'jfku.edu': 'John F. Kennedy University',
#  'jh.edu': 'Johns Hopkins University',
#  'jhu.edu': 'Johns Hopkins University',
#  'jhuapl.edu': 'Johns Hopkins University Applied Physics Laboratory',
#  'jwu.edu': 'Johnson & Wales University',
#  'jbc.edu': 'Johnson Bible College',
#  'jcsu.edu': 'Johnson C. Smith University',
#  'jones.edu': 'Jones College',
#  'judson.edu': 'Judson College',
#  'juniata.edu': 'Juniata College',
#  'kzoo.edu': 'Kalamazoo College',
#  'ksu.edu': 'Kansas State University',
#  'kwu.edu': 'Kansas Wesleyan University',
#  'kaplan.edu': 'Kaplan University',
#  'kean.edu': 'Kean College',
#  'keene.edu': 'Keene State College',
#  'kennesaw.edu': 'Kennesaw State University',
#  'kent.edu': 'Kent State University',
#  'kctcs.edu': 'Kentucky Community & Technical College System',
#  'kenyon.edu': 'Kenyon College',
#  'kettering.edu': 'Kettering University',
#  'kings.edu': "King's College",
#  'knox.edu': 'Knox College',
#  'kutztown.edu': 'Kutztown University of Pennsylvania',
#  'lafayette.edu': 'Lafayette College',
#  'lagrange.edu': 'LaGrange College',
#  'lfc.edu': 'Lake Forest College',
#  'lsc.edu': 'Lake Superior College',
#  'lssu.edu': 'Lake Superior State University',
#  'lamar.edu': 'Lamar University',
#  'lambtoncollege.ca': 'Lambton College',
#  'mylambton.ca': 'Lambton College',
#  'langston.edu': 'Langston University',
#  'lasalle.edu': 'LaSalle University',
#  'lasierra.edu': 'La Sierra University',
#  'ltu.edu': 'Lawrence Technological University',
#  'lawrence.edu': 'Lawrence University',
#  'lvc.edu': 'Lebanon Valley College',
#  'lehigh.edu': 'Lehigh University',
#  'lemoyne.edu': 'Le Moyne College',
#  'lenoircc.edu': 'Lenoir Community College',
#  'lrc.edu': 'Lenoir-Rhyne College',
#  'letu.edu': 'LeTourneau University',
#  'lclark.edu': 'Lewis & Clark College',
#  'lcsc.edu': 'Lewis-Clark State College',
#  'lewisu.edu': 'Lewis University',
#  'liberty.edu': 'Liberty University',
#  'lincoln.edu': 'Lincoln University',
#  'linfield.edu': 'Linfield College',
#  'lhup.edu': 'Lock Haven University',
#  'lockhaven.edu': 'Lock Haven University',
#  'llu.edu': 'Loma Linda University',
#  'liunet.edu': 'Long Island University',
#  'longwood.edu': 'Longwood University',
#  'loras.edu': 'Loras College',
#  'laccd.edu': 'Los Angeles Community College District',
#  'lacollege.edu': 'Louisiana College',
#  'lsu.edu': 'Louisiana State University',
#  'lsua.edu': 'Louisiana State University at Alexandria',
#  'latech.edu': 'Louisiana Tech University',
#  'loyola.edu': 'Loyola College',
#  'lmu.edu': 'Loyola Marymount University',
#  'luc.edu': 'Loyola University Chicago',
#  'luther.edu': 'Luther College',
#  'luthersem.edu': 'Luther Seminary',
#  'lycoming.edu': 'Lycoming College',
#  'lynchburg.edu': 'Lynchburg College',
#  'lyndonstate.edu': 'Lyndon State College',
#  'lyon.edu': 'Lyon College',
#  'macalester.edu': 'Macalester College',
#  'mum.edu': 'Maharishi University of Management',
#  'malone.edu': 'Malone College',
#  'manhattan.edu': 'Manhattan College',
#  'mansfield.edu': 'Mansfield University of Pennsylvania',
#  'maricopa.edu': 'Maricopa County Community College District',
#  'marietta.edu': 'Marietta College',
#  'marist.edu': 'Marist College',
#  'marlboro.edu': 'Marlboro College',
#  'marquette.edu': 'Marquette University',
#  'marshall.edu': 'Marshall University',
#  'mbc.edu': 'Mary Baldwin College',
#  'mmm.edu': 'Marymount Manhattan College',
#  'marymount.edu': 'Marymount University',
#  'mwc.edu': 'Mary Washington College',
#  'mit.edu': 'Massachusetts Institute of Technology',
#  'mcdaniel.edu': 'McDaniel College',
#  'mcm.edu': 'McMurry University',
#  'mcneese.edu': 'McNeese State University',
#  'mcg.edu': 'Medical College of Georgia',
#  'mcw.edu': 'Medical College of Wisconsin',
#  'mccc.edu': 'Mercer County Community College',
#  'mercer.edu': 'Mercer University',
#  'mercymavericks.edu': 'Mercy College',
#  'mercy.edu': 'Mercy College',
#  'mercyhurst.edu': 'Mercyhurst College',
#  'meredith.edu': 'Meredith College',
#  'messiah.edu': 'Messiah College',
#  'mcckc.edu': 'Metropolitan Community College (MO)',
#  'mccneb.edu': 'Metropolitan Community College (NE)',
#  'msudenver.edu': 'Metropolitan State College of Denver',
#  'metrostate.edu': 'Metropolitan State University',
#  'miamioh.edu': 'Miami University of Ohio',
#  'msu.edu': 'Michigan State University',
#  'mtu.edu': 'Michigan Technological University',
#  'manc.edu': 'Mid-America Nazarene College',
#  'middlebury.edu': 'Middlebury College',
#  'mga.edu': 'Middle Georgia State College',
#  'mtsu.edu': 'Middle Tennessee State University',
#  'mwsu.edu': 'Midwestern State University',
#  'millersville.edu': 'Millersville University of Pennsylvania',
#  'milligan.edu': 'Milligan College',
#  'millikin.edu': 'Millikin University',
#  'millsaps.edu': 'Millsaps College',
#  'msoe.edu': 'Milwaukee School of Engineering',
#  'mcad.edu': 'Minneapolis College of Art and Design',
#  'mnsu.edu': 'Minnesota State University, Mankato',
#  'mnstate.edu': 'Minnesota State University Moorhead',
#  'minotstateu.edu': 'Minot State University',
#  'mc.edu': 'Mississippi College',
#  'msstate.edu': 'Mississippi State University',
#  'muw.edu': 'Mississippi University for Women',
#  'mssc.edu': 'Missouri Southern State College',
#  'mst.edu': 'Missouri University of Science and Technology',
#  'mwsc.edu': 'Missouri Western State College',
#  'molloy.edu': 'Molloy College',
#  'monmouthcollege.edu': 'Monmouth College',
#  'monmouth.edu': 'Monmouth University',
#  'msubillings.edu': 'Montana State University - Billings',
#  'montana.edu': 'Montana State University - Bozeman',
#  'msun.edu': 'Montana State University - Northern',
#  'mtech.edu': 'Montana Tech',
#  'montclair.edu': 'Montclair State University',
#  'montgomerycollege.edu': 'Montgomery College',
#  'montreat.edu': 'Montreat College',
#  'moravian.edu': 'Moravian College',
#  'morgan.edu': 'Morgan State University',
#  'mcc.edu': 'Mott Community College',
#  'mtholyoke.edu': 'Mount Holyoke College',
#  'msj.edu': 'Mount Saint Joseph College',
#  'msmc.edu': 'Mount Saint Mary College',
#  'mscfs.edu': 'Mount Senario College',
#  'muc.edu': 'Mount Union College',
#  'mursuky.edu': 'Murray State University',
#  'muskingum.edu': 'Muskingum College',
#  'nscc.edu': 'Nashville State Community College',
#  'ndu.edu': 'National Defense University',
#  'nl.edu': 'National-Louis University',
#  'nrao.edu': 'National Radio Astronomy Observatory',
#  'ntu.edu': 'National Technological University',
#  'nu.edu': 'National University',
#  'nps.edu': 'Naval Postgraduate School',
#  'naz.edu': 'Nazareth College',
#  'nevada.edu': 'Nevada System of Higher Education',
#  'newberry.edu': 'Newberry College',
#  'newcollege.edu': 'New College of California',
#  'neit.edu': 'New England Institute of Technology',
#  'nhc.edu': 'New Hampshire College',
#  'njit.edu': 'New Jersey Institute of Technology',
#  'nmhu.edu': 'New Mexico Highlands University',
#  'nmt.edu': 'New Mexico Institute of Mining & Technology',
#  'nmsu.edu': 'New Mexico State University',
#  'nyit.edu': 'New York Institute of Technology',
#  'nyu.edu': 'New York University',
#  'niagara.edu': 'Niagara University',
#  'nicholls.edu': 'Nicholls State University',
#  'nsu.edu': 'Norfolk State University',
#  'na.edu': 'North American University',
#  'northampton.edu': 'Northampton Community College',
#  'ncat.edu': 'North Carolina A&T State University',
#  'nccu.edu': 'North Carolina Central University',
#  'ncsu.edu': 'North Carolina State University',
#  'ncwc.edu': 'North Carolina Wesleyan College',
#  'ncbc.edu': 'North Central Bible College',
#  'ndsu.edu': 'North Dakota State University',
#  'nlu.edu': 'Northeastern Louisiana University',
#  'nsuok.edu': 'Northeastern State University',
#  'neu.edu': 'Northeastern University',
#  'northeastern.edu': 'Northeastern University',
#  'nau.edu': 'Northern Arizona University',
#  'niu.edu': 'Northern Illinois University',
#  'nku.edu': 'Northern Kentucky University',
#  'nmu.edu': 'Northern Michigan University',
#  'northern.edu': 'Northern State University',
#  'northland.edu': 'Northland College',
#  'npcts.edu': 'North Park College and Theological Seminary',
#  'nwciowa.edu': 'Northwestern College of Iowa',
#  'nsula.edu': 'Northwestern State University',
#  'northwestern.edu': 'Northwestern University',
#  'nwmissouri.edu': 'Northwest Missouri State University',
#  'nnc.edu': 'Northwest Nazarene College',
#  'norwich.edu': 'Norwich University',
#  'nova.edu': 'Nova Southeastern University',
#  'oakland.edu': 'Oakland University',
#  'oakwood.edu': 'Oakwood University',
#  'oberlin.edu': 'Oberlin College',
#  'oxy.edu': 'Occidental College',
#  'odc.edu': 'Ohio Dominican College',
#  'onu.edu': 'Ohio Northern University',
#  'osu.edu': 'Ohio State University, Columbus',
#  'ohio.edu': 'Ohio University',
#  'ohiou.edu': 'Ohio University',
#  'owu.edu': 'Ohio Wesleyan University',
#  'okbu.edu': 'Oklahoma Baptist University',
#  'okcu.edu': 'Oklahoma City University',
#  'okstate.edu': 'Oklahoma State University',
#  'odu.edu': 'Old Dominion University',
#  'olivet.edu': 'Olivet Nazarene University',
#  'oru.edu': 'Oral Roberts University',
#  'ogi.edu': 'Oregon Graduate Institute of Science and Technology',
#  'ohsu.edu': 'Oregon Health Sciences University',
#  'oit.edu': 'Oregon Institute of Technology',
#  'oregonstate.edu': 'Oregon State University',
#  'otterbein.edu': 'Otterbein College',
#  'ollusa.edu': 'Our Lady of the Lake University',
#  'pace.edu': 'Pace University',
#  'plu.edu': 'Pacific Lutheran University',
#  'puc.edu': 'Pacific Union College',
#  'pacificu.edu': 'Pacific University',
#  'pwu.com': 'Pacific Western University',
#  'pbac.edu': 'Palm Beach Atlantic College',
#  'palmbeachstate.edu': 'Palm Beach State College',
#  'peace.edu': 'Peace College',
#  'pembroke.edu': 'Pembroke State University',
#  'pct.edu': 'Pennsylvania College of Technology',
#  'psu.edu': 'Pennsylvania State University',
#  'sl.psu.edu': 'Pennsylvania State University - Schuylkill Campus',
#  'pcci.edu': 'Pensacola Christian College',
#  'pensacolastate.edu': 'Pensacola State College',
#  'pepperdine.edu': 'Pepperdine University',
#  'peru.edu': 'Peru State College',
#  'philau.edu': 'Philadelphia University',
#  'phillips.edu': 'Phillips University',
#  'pittstate.edu': 'Pittsburg State University',
#  'pitzer.edu': 'Pitzer College',
#  'platt.edu': 'Platt College',
#  'plymouth.edu': 'Plymouth State College',
#  'poly.edu': 'Polytechnic University of New York',
#  'pupr.edu': 'Universidad Politecnica de Puerto Rico',
#  'pomona.edu': 'Pomona College',
#  'pcc.edu': 'Portland Community College',
#  'pdx.edu': 'Portland State University',
#  'pvamu.edu': 'Prairie View A&M University',
#  'pratt.edu': 'Pratt Institute',
#  'presby.edu': 'Presbyterian College',
#  'prescott.edu': 'Prescott College',
#  'princeton.edu': 'Princeton University',
#  'providence.edu': 'Providence College',
#  'purdue.edu': 'Purdue University',
#  'purduecal.edu': 'Purdue University Calumet',
#  'pnc.edu': 'Purdue University North Central',
#  'quincy.edu': 'Quincy University',
#  'quinnipiac.edu': 'Quinnipiac College',
#  'radford.edu': 'Radford University',
#  'ramapo.edu': 'Ramapo College',
#  'rmc.edu': 'Randolph-Macon College',
#  'rmwc.edu': "Randolph-Macon Woman's College",
#  'reed.edu': 'Reed College',
#  'regent.edu': 'Regent University',
#  'regis.edu': 'Regis University',
#  'rpi.edu': 'Rensselaer Polytechnic Institute',
#  'ric.edu': 'Rhode Island College',
#  'rhodes.edu': 'Rhodes College',
#  'rice.edu': 'Rice University',
#  'stockton.edu': 'Richard Stockton College of New Jersey',
#  'rider.edu': 'Rider University',
#  'ripon.edu': 'Ripon College',
#  'riv.edu': 'Rivier College',
#  'roanoke.edu': 'Roanoke College',
#  'rmu.edu': 'Robert Morris University',
#  'rit.edu': 'Rochester Institute of Technology',
#  'rockefeller.edu': 'Rockefeller University',
#  'rockford.edu': 'Rockford College',
#  'rockhurst.edu': 'Rockhurst College',
#  'rocky.edu': 'Rocky Mountain College',
#  'rwu.edu': 'Roger Williams University',
#  'rollins.edu': 'Rollins College',
#  'rosary.edu': 'Rosary College',
#  'rose-hulman.edu': 'Rose-Hulman Institute of Technology',
#  'rowan.edu': 'Rowan College',
#  'rutgers.edu': 'Rutgers University, Newark',
#  'sacredheart.edu': 'Sacred Heart University',
#  'sage.edu': 'Sage Colleges',
#  'svsu.edu': 'Saginaw Valley State University',
#  'anselm.edu': 'Saint Anselm College',
#  'stcloudstate.edu': 'Saint Cloud State University',
#  'stedwards.edu': "Saint Edward's University",
#  'sfcpa.edu': 'Saint Francis College',
#  'stjohns.edu': "Saint John's University (NY)",
#  'saintjoe.edu': "Saint Joseph's College (IN)",
#  'sju.edu': "Saint Joseph's University",
#  'saintleo.edu': 'Saint Leo University',
#  'slu.edu': 'Saint Louis University',
#  'smcks.edu': 'Saint Mary College',
#  'saintmarys.edu': "Saint Mary's College (IN)",
#  'stmarys-ca.edu': "Saint Mary's College of California",
#  'smumn.edu': "Saint Mary's University of Minnesota",
#  'smcvt.edu': "Saint Michael's College",
#  'stolaf.edu': 'Saint Olaf College',
#  'stvincent.edu': 'Saint Vincent College',
#  'sxu.edu': 'Saint Xavier University',
#  'salisbury.edu': 'Salisbury University',
#  'skc.edu': 'Salish Kootenai College',
#  'samford.edu': 'Samford University',
#  'shsu.edu': 'Sam Houston State University',
#  'sdsu.edu': 'San Diego State University',
#  'sfsu.edu': 'San Francisco State University',
#  'scu.edu': 'Santa Clara University',
#  'slc.edu': 'Sarah Lawrence College',
#  'saic.edu': 'School of the Art Institute of Chicago',
#  'seattlecentral.edu': 'Seattle Central College',
#  'spu.edu': 'Seattle Pacific University',
#  'seattleu.edu': 'Seattle University',
#  'shu.edu': 'Seton Hall University',
#  'sewanee.edu': 'Sewanee, University of the South',
#  'shawnee.edu': 'Shawnee State University',
#  'su.edu': 'Shenandoah University',
#  'ship.edu': 'Shippensburg University of Pennsylvania',
#  'shorter.edu': 'Shorter College',
#  'simmons.edu': 'Simmons College',
#  'simons-rock.edu': "Simon's Rock College",
#  'simpson.edu': 'Simpson College',
#  'sinclair.edu': 'Sinclair Community College',
#  'skidmore.edu': 'Skidmore College',
#  'sru.edu': 'Slippery Rock University of Pennsylvania',
#  'smith.edu': 'Smith College',
#  'sonoma.edu': 'Sonoma State University',
#  'sdsmt.edu': 'South Dakota School of Mines and Technology',
#  'sdstate.edu': 'South Dakota State University',
#  'selu.edu': 'Southeastern Louisiana University',
#  'semo.edu': 'Southeast Missouri State University',
#  'southern.edu': 'Southern College',
#  'sct.edu': 'Southern College of Technology',
#  'southernct.edu': 'Southern Connecticut State University',
#  'siu.edu': 'Southern Illinois University-Carbondale',
#  'siue.edu': 'Southern Illinois University-Edwardsville',
#  'smu.edu': 'Southern Methodist University',
#  'snu.edu': 'Southern Nazarene University',
#  'snhu.edu': 'Southern New Hampshire University',
#  'sou.edu': 'Southern Oregon State College',
#  'subr.edu': 'Southern University and A&M College',
#  'suu.edu': 'Southern Utah University',
#  'stcl.edu': 'South Texas College of Law',
#  'sbuniv.edu': 'Southwest Baptist University',
#  'swac.edu': 'Southwestern Adventist College',
#  'sagu.edu': 'Southwestern Assemblies of God University',
#  'sckans.edu': 'Southwestern College (KS)',
#  'southwestern.edu': 'Southwestern University',
#  'smsu.edu': 'Southwest Missouri State University',
#  'swt.edu': 'Southwest Texas State University',
#  'auc.edu': 'Spelman College',
#  'arbor.edu': 'Spring Arbor College',
#  'shc.edu': 'Spring Hill College',
#  'sau.edu': 'St. Ambrose University',
#  'sapc.edu': 'St. Andrews Presbyterian College',
#  'stanford.edu': 'Stanford University',
#  'albany.edu': 'State University of New York at Albany',
#  'binghamton.edu': 'State University of New York at Binghamton',
#  'buffalo.edu': 'State University of New York at Buffalo',
#  'farmingdale.edu': 'State University of New York at Farmingdale',
#  'fredonia.edu': 'State University of New York at Fredonia',
#  'oswego.edu': 'State University of New York at Oswego',
#  'plattsburgh.edu': 'State University of New York at Plattsburgh',
#  'stonybrook.edu': 'State University of New York at Stony Brook',
#  'stonybrookmedicine.edu': 'Academic medical center at State University of New York at Stony Brook',
#  'brockport.edu': 'State University of New York College at Brockport',
#  'buffalostate.edu': 'State University of New York College at Buffalo',
#  'cortland.edu': 'State University of New York College at Cortland',
#  'geneseo.edu': 'State University of New York College at Geneseo',
#  'newpaltz.edu': 'State University of New York College at New Paltz',
#  'potsdam.edu': 'State University of New York College at Potsdam',
#  'cobleskill.edu': 'State University of New York College of Agriculture and Technology at Cobleskill',
#  'esf.edu': 'State University of New York College of Environmental Science and Forestry',
#  'alfredtech.edu': 'State University of New York College of Technology at Alfred',
#  'sunyit.edu': 'State University of New York Polytechnic Institute',
#  'sunycentral.edu': 'State University of New York System',
#  'sbu.edu': 'St. Bonaventure University',
#  'sfasu.edu': 'Stephen F. Austin State University',
#  'stephens.edu': 'Stephens College',
#  'stetson.edu': 'Stetson University',
#  'stevens.edu': 'Stevens Institute of Technology',
#  'stevens-tech.edu': 'Stevens Institute of Technology',
#  'sjca.edu': "St. John's College - Annapolis",
#  'sjcsf.edu': "St. John's College - Santa Fe",
#  'sjc.edu': 'St. Joseph College (CT)',
#  'sjcme.edu': "St. Joseph's College (ME)",
#  'stlawu.edu': 'St. Lawrence University',
#  'stlcop.edu': 'St. Louis College of Pharmacy',
#  'stmartin.edu': "St. Martin's College",
#  'smcm.edu': "St. Mary's College of Maryland",
#  'strayer.edu': 'Strayer College',
#  'stu.edu': 'St. Thomas University (FL)',
#  'suffolk.edu': 'Suffolk University',
#  'sulross.edu': 'Sul Ross State University',
#  'summitunivofla.edu': 'Summit University of Louisiana',
#  'susqu.edu': 'Susquehanna University',
#  'swarthmore.edu': 'Swarthmore College',
#  'sbc.edu': 'Sweet Briar College',
#  'syr.edu': 'Syracuse University',
#  'tabor.edu': 'Tabor College',
#  'tarleton.edu': 'Tarleton State University',
#  'tayloru.edu': 'Taylor University',
#  'temple.edu': 'Temple University',
#  'tnstate.edu': 'Tennessee State University',
#  'tntech.edu': 'Tennessee Technological University',
#  'tccd.edu': 'Terrant County College',
#  'tamiu.edu': 'Texas A&M International University',
#  'tamu.edu': 'Texas A&M University - College Station',
#  'tamuc.edu': 'Texas A&M University - Commerce',
#  'tamucc.edu': 'Texas A&M University - Corpus Christi',
#  'tamuk.edu': 'Texas A&M University - Kingsville',
#  'tcu.edu': 'Texas Christian University',
#  'tsu.edu': 'Texas Southern University',
#  'txstate.edu': 'Texas State University',
#  'ttu.edu': 'Texas Tech University',
#  'ttuhsc.edu': 'Texas Tech University-Health Sciences Center',
#  'twu.edu': "Texas Woman's University",
#  'citadel.edu': 'The Citadel',
#  'jtsa.edu': 'The Jewish Theological Seminary',
#  'thomas.edu': 'Thomas College',
#  'tesc.edu': 'Thomas Edison State University',
#  'tju.edu': 'Thomas Jefferson University',
#  'thomasmore.edu': 'Thomas More College',
#  'thunderbird.edu': 'Thunderbird School of Global Management',
#  'towson.edu': 'Towson University',
#  'transy.edu': 'Transylvania University',
#  'trenton.edu': 'Trenton State College',
#  'trine.edu': 'Trine University',
#  'trincoll.edu': 'Trinity College (CT)',
#  'trinitydc.edu': 'Trinity College (DC)',
#  'trinity.edu': 'Trinity University',
#  'tsufl.edu': 'Troy State University',
#  'truman.edu': 'Truman State University',
#  'tucsonu.edu': 'Tucson University',
#  'tufts.edu': 'Tufts University',
#  'tulane.edu': 'Tulane University',
#  'tuskegee.edu': 'Tuskegee University',
#  'usuhs.mil': 'Uniformed Services University of the Health Sciences',
#  'union.edu': 'Union College',
#  'tui.edu': 'Union Institute',
#  'uu.edu': 'Union University',
#  'usafa.af.mil': 'United States Air Force Academy',
#  'usafa.edu': 'United States Air Force Academy',
#  'usiu.edu': 'United States International University',
#  'usmma.edu': 'United States Merchant Marine Academy',
#  'usma.edu': 'United States Military Academy',
#  'usna.edu': 'United States Naval Academy',
#  'uat.edu': 'University of Advancing Technology',
#  'uakron.edu': 'University of Akron',
#  'uab.edu': 'University of Alabama at Birmingham',
#  'uah.edu': 'University of Alabama at Huntsville',
#  'ua.edu': 'University of Alabama at Tuscaloosa',
#  'alaska.edu': 'University of Alaska',
#  'uaa.alaska.edu': 'University of Alaska - Anchorage',
#  'uaf.edu': 'University of Alaska - Fairbanks',
#  'uas.alaska.edu': 'University of Alaska - Southeast',
#  'arizona.edu': 'University of Arizona',
#  'uark.edu': 'University of Arkansas - Fayetteville',
#  'uams.edu': 'University of Arkansas for Medical Sciences',
#  'ualr.edu': 'University of Arkansas - Little Rock',
#  'uamont.edu': 'University of Arkansas - Monticello',
#  'ubalt.edu': 'University of Baltimore',
#  'bridgeport.edu': 'University of Bridgeport',
#  'berkeley.edu': 'University of California, Berkeley',
#  'ucdavis.edu': 'University of California, Davis',
#  'uci.edu': 'University of California, Irvine',
#  'ucla.edu': 'University of California, Los Angeles',
#  'ucmerced.edu': 'University of California, Merced',
#  'ucr.edu': 'University of California, Riverside',
#  'ucsd.edu': 'University of California, San Diego',
#  'ucsf.edu': 'University of California, San Francisco',
#  'ucsb.edu': 'University of California, Santa Barbara',
#  'ucsc.edu': 'University of California, Santa Cruz',
#  'uca.edu': 'University of Central Arkansas',
#  'ucf.edu': 'University of Central Florida',
#  'ucmo.edu': 'University of Central Missouri',
#  'uchaswv.edu': 'University of Charleston',
#  'uchicago.edu': 'University of Chicago',
#  'uc.edu': 'University of Cincinnati',
#  ...}

# %%
#adding in the most common university names not in json
mapping['nie.edu.sg'] = "National Institute of Education (NIE), Singapore"
mapping['rub.de'] = "Ruhr-University Bochum"
mapping['uni-due.de'] = "Universität Duisburg-Essen"
mapping['collide.info'] = "Universität Duisburg-Essen"
mapping['dawsoncollege.qc.ca'] = "Dawson College"
mapping['dawsoncollege.ca'] = "Dawson College"
mapping['johnabbott.qc.ca'] = "John Abbott College"
mapping['johnabbott.ca'] = "John Abbott College"
mapping['vaniercollege.qc.ca'] = 'Vanier Colleege'

# %%
def get_school_from_mail(mail, mapping):
    """maps email to institution"""
    if mail in mapping:
        return (mapping[mail], mail)
    elif re.findall('[a-zA-Z0-9\-]*\.[a-zA-Z0-9\-]*$', mail)[0] in mapping:
        double = re.findall('[a-zA-Z0-9\-]*\.[a-zA-Z0-9\-]*$', mail)[0]
        return (mapping[double], double)
    else:
        triplet = re.findall('[a-zA-Z0-9\-]*\.[a-zA-Z0-9\-]*\.[a-zA-Z0-9\-]*$', mail)
        if len(triplet) > 0 and triplet[0] in mapping:
            return (mapping[triplet[0]], triplet[0])
        else:
            return (np.nan, mail)

# %%
institution = []
j = 0
for i, text in enumerate(contents):
    abstract_pos = text.find('\nAbstract')
    mails_in_paper = re.findall('[a-zA-Z0-9\.\-]*@[a-zA-Z0-9\.\-]*\.[a-zA-Z0-9\.\-]*(?!\S*\:\S*)', text[:text.lower().find('\nAbstract')])
    j += len(mails_in_paper)
    institution.append([(get_school_from_mail(m.split('@')[1].lower(), mapping), m, i) for i, m in enumerate(mails_in_paper)])

# %%
len(institution), len(contents)
# Out:
# (874, 874)

# %%
j
# Out:
# 3242

# %%
j
# Out:
# 3242

# %%
inst = pd.DataFrame([(i[0][0],i[0][1], i[1],i[2], source[index]) for index, uni in enumerate(institution) for i in uni ], 
                    columns=['name', 'domain', 'mail','authorindex','file'])

# %%
inst.shape
# Out:
# (3242, 5)

# %%
inst[inst['name'].isna()].shape
# Out:
# (552, 5)

# %% [markdown]
# 1/5 are not found

# %%
inst[inst['name'].isna()].shape[0]/inst.shape[0]
# Out:
# 0.1702652683528686

# %% [markdown]
# Quick look at the most productive universities:

# %%
inst.name.value_counts().head(20).plot(kind='bar')

# %% [markdown]
# Most unfound (1/3) ones are gmail.
# We can see that some universities that are common in here are missing from the university list!
# There are some spelling errors :/
# May use edit distance 1 or 2 to still parse maybe?

# %%
def get_org_name(x):
    
    candidates = x.split('.')
    lengths = np.array([len(z) for z in candidates])
    
    for c in candidates:
        if c in ['qq','sina','163']:
            return c
    return candidates[lengths.argmax()]

# %%
inst.loc[inst['name'].isna(),'name'] = inst[inst['name'].isna()].domain.map(lambda x: get_org_name(x))

# %% [markdown]
# Here we can add the country:

# %%
#There are two saint luis universities in the world...

# %%
country_uni
# Out:
# {'cstj.qc.ca': 'Canada',
#  'lindenwood.edu': 'United States',
#  'davietjal.org': 'India',
#  'lpu.in': 'India',
#  'sullivan.edu': 'United States',
#  'fscj.edu': 'United States',
#  'xavier.edu': 'United States',
#  'tusculum.edu': 'United States',
#  'cst.edu': 'United States',
#  'somaiya.edu': 'India',
#  'columbiasc.edu': 'United States',
#  'clpccd.edu': 'United States',
#  'keller.edu': 'United States',
#  'monroecollege.edu': 'United States',
#  'smccd.edu': 'United States',
#  'losrios.edu': 'United States',
#  'digipen.edu': 'United States',
#  'upmc.edu': 'United States',
#  'upmc.com': 'United States',
#  'cgu.edu': 'United States',
#  'utrgv.edu': 'United States',
#  'mountsaintvincent.edu': 'United States',
#  'uasys.edu': 'United States',
#  'ecpi.edu': 'United States',
#  'umw.edu': 'United States',
#  'bw.edu': 'United States',
#  'csuci.edu': 'United States',
#  'brandman.edu': 'United States',
#  'uscga.edu': 'United States',
#  'athens.edu': 'United States',
#  'scripps.edu': 'United States',
#  'easternflorida.edu': 'United States',
#  'wne.edu': 'United States',
#  'king.edu': 'United States',
#  'ggc.edu': 'United States',
#  'trident.edu': 'United States',
#  'alliant.edu': 'United States',
#  'mvsu.edu': 'United States',
#  'roosevelt.edu': 'United States',
#  'itt-tech.info': 'United States',
#  'itt-tech.edu': 'United States',
#  'iecc.edu': 'United States',
#  'park.edu': 'United States',
#  'mssm.edu': 'United States',
#  'uvu.edu': 'United States',
#  'wlc.edu': 'United States',
#  'rccd.edu': 'United States',
#  'wakehealth.edu': 'United States',
#  'umb.edu': 'United States',
#  'floridapoly.edu': 'United States',
#  'wagner.edu': 'United States',
#  'wilmu.edu': 'United States',
#  'itu.edu': 'United States',
#  'yhc.edu': 'United States',
#  'findlay.edu': 'United States',
#  'pcom.edu': 'United States',
#  'yosemite.edu': 'United States',
#  'coastalalabama.edu': 'United States',
#  'pnw.edu': 'United States',
#  'columbiabasin.edu': 'United States',
#  'seattlecolleges.edu': 'United States',
#  'lipscomb.edu': 'United States',
#  'tiffin.edu': 'United States',
#  'ncuindia.edu': 'India',
#  'troy.edu': 'United States',
#  'student.42.us.org': 'United States',
#  'calbaptist.edu': 'United States',
#  'stevenson.edu': 'United States',
#  'mbl.edu': 'United States',
#  'maryville.edu': 'United States',
#  'aii.edu': 'United States',
#  'umc.edu': 'United States',
#  'uco.edu': 'United States',
#  'hallmarkuniversity.edu': 'United States',
#  'keiseruniversity.edu': 'United States',
#  'sjrstate.edu': 'United States',
#  'irsc.edu': 'United States',
#  'barnard.edu': 'United States',
#  'tesu.edu': 'United States',
#  'calsouthern.edu': 'United States',
#  'laverne.edu': 'United States',
#  'washjeff.edu': 'United States',
#  'uopeople.edu': 'United States',
#  'touro.edu': 'United States',
#  'njcu.edu': 'United States',
#  'lander.edu': 'United States',
#  'sunymaritime.edu': 'United States',
#  'lesley.edu': 'United States',
#  'lauruscollege.edu': 'United States',
#  'np.edu': 'United States',
#  'oc.edu': 'United States',
#  'sdcc.edu': 'United States',
#  'sans.edu': 'United States',
#  'phsc.edu': 'United States',
#  'ncf.edu': 'United States',
#  'gcu.edu': 'United States',
#  'cshl.edu': 'United States',
#  'asurams.edu': 'United States',
#  'lasell.edu': 'United States',
#  '4cd.edu': 'United States',
#  'msmary.edu': 'United States',
#  'robertmorris.edu': 'United States',
#  'nwfsc.edu': 'United States',
#  'wvwc.edu': 'United States',
#  'utica.edu': 'United States',
#  'ccnn.edu': 'United States',
#  'ung.edu': 'United States',
#  'principia.edu': 'United States',
#  'lynn.edu': 'United States',
#  'cccs.edu': 'United States',
#  'valenciacollege.edu': 'United States',
#  'spcollege.edu': 'United States',
#  'msbcollege.edu': 'United States',
#  'everest.edu': 'United States',
#  'swri.edu': 'United States',
#  'apus.edu': 'United States',
#  'fullsail.edu': 'United States',
#  'yti.edu': 'United States',
#  'dliflc.edu': 'United States',
#  'columbusstate.edu': 'United States',
#  'moreheadstate.edu': 'United States',
#  'csuglobal.edu': 'United States',
#  'ndus.edu': 'United States',
#  'uhd.edu': 'United States',
#  'stratford.edu': 'United States',
#  'cpp.edu': 'United States',
#  'baker.edu': 'United States',
#  'tcnj.edu': 'United States',
#  'acu.edu': 'United States',
#  'adelphi.edu': 'United States',
#  'agnesscott.edu': 'United States',
#  'atc.edu': 'United States',
#  'afit.af.mil': 'United States',
#  'afit.edu': 'United States',
#  'aamu.edu': 'United States',
#  'alasu.edu': 'United States',
#  'aloma.edu': 'United States',
#  'acofi.edu': 'United States',
#  'albion.edu': 'United States',
#  'alfred.edu': 'United States',
#  'alleg.edu': 'United States',
#  'allencol.edu': 'United States',
#  'alma.edu': 'United States',
#  'alverno.edu': 'United States',
#  'ambassador.edu': 'United States',
#  'amercoastuniv.edu': 'United States',
#  'aic.edu': 'United States',
#  'american.edu': 'United States',
#  'amherst.edu': 'United States',
#  'andrews.edu': 'United States',
#  'angelo.edu': 'United States',
#  'aacc.edu': 'United States',
#  'antiochne.edu': 'United States',
#  'antioch.edu': 'United States',
#  'antiochla.edu': 'United States',
#  'seattleantioch.edu': 'United States',
#  'appstate.edu': 'United States',
#  'aquinas.edu': 'United States',
#  'arcadia.edu': 'United States',
#  'asu.edu': 'United States',
#  'azwestern.edu': 'United States',
#  'astate.edu': 'United States',
#  'atu.edu': 'United States',
#  'armstrong.edu': 'United States',
#  'ashland.edu': 'United States',
#  'assumption.edu': 'United States',
#  'auburn.edu': 'United States',
#  'aum.edu': 'United States',
#  'augsburg.edu': 'United States',
#  'augustana.edu': 'United States',
#  'augie.edu': 'United States',
#  'augusta.edu': 'United States',
#  'gru.edu': 'United States',
#  'aurora.edu': 'United States',
#  'austincollege.edu': 'United States',
#  'austincc.edu': 'United States',
#  'apsu.edu': 'United States',
#  'averett.edu': 'United States',
#  'avila.edu': 'United States',
#  'apu.edu': 'United States',
#  'babson.edu': 'United States',
#  'bakeru.edu': 'United States',
#  'bsu.edu': 'United States',
#  'bbc.edu': 'United States',
#  'bard.edu': 'United States',
#  'barry.edu': 'United States',
#  'bastyr.edu': 'United States',
#  'bates.edu': 'United States',
#  'bcm.edu': 'United States',
#  'baylor.edu': 'United States',
#  'bellevue.edu': 'United States',
#  'belmont.edu': 'United States',
#  'beloit.edu': 'United States',
#  'bemidjistate.edu': 'United States',
#  'benedictine.edu': 'United States',
#  'bennington.edu': 'United States',
#  'bentley.edu': 'United States',
#  'berea.edu': 'United States',
#  'berklee.edu': 'United States',
#  'bethanywv.edu': 'United States',
#  'bethelks.edu': 'United States',
#  'bethel.edu': 'United States',
#  'biola.edu': 'United States',
#  'bsc.edu': 'United States',
#  'bhsu.edu': 'United States',
#  'bloomu.edu': 'United States',
#  'bluffton.edu': 'United States',
#  'bju.edu': 'United States',
#  'idbsu.edu': 'United States',
#  'boisestate.edu': 'United States',
#  'bc.edu': 'United States',
#  'bgsp.edu': 'United States',
#  'bu.edu': 'United States',
#  'bowdoin.edu': 'United States',
#  'bowiestate.edu': 'United States',
#  'bgsu.edu': 'United States',
#  'bradley.edu': 'United States',
#  'brandeis.edu': 'United States',
#  'brenau.edu': 'United States',
#  'briar-cliff.edu': 'United States',
#  'bridgewater.edu': 'United States',
#  'byu.edu': 'United States',
#  'byui.edu': 'United States',
#  'byuh.edu': 'United States',
#  'broward.edu': 'United States',
#  'brown.edu': 'United States',
#  'bryant.edu': 'United States',
#  'brynmawr.edu': 'United States',
#  'bucknell.edu': 'United States',
#  'bvu.edu': 'United States',
#  'butler.edu': 'United States',
#  'calcoast.edu': 'United States',
#  'caltech.edu': 'United States',
#  'callutheran.edu': 'United States',
#  'csum.edu': 'United States',
#  'cnuas.edu': 'United States',
#  'calpoly.edu': 'United States',
#  'csub.edu': 'United States',
#  'csubak.edu': 'United States',
#  'csuchico.edu': 'United States',
#  'csudh.edu': 'United States',
#  'csufresno.edu': 'United States',
#  'fresnostate.edu': 'United States',
#  'fullerton.edu': 'United States',
#  'csuhayward.edu': 'United States',
#  'csulb.edu': 'United States',
#  'calstatela.edu': 'United States',
#  'monterey.edu': 'United States',
#  'csun.edu': 'United States',
#  'csus.edu': 'United States',
#  'csusb.edu': 'United States',
#  'sjsu.edu': 'United States',
#  'csusm.edu': 'United States',
#  'csustan.edu': 'United States',
#  'calstate.edu': 'United States',
#  'cup.edu': 'United States',
#  'calvin.edu': 'United States',
#  'cameron.edu': 'United States',
#  'campbellsville.edu': 'United States',
#  'campbell.edu': 'United States',
#  'canisius.edu': 'United States',
#  'capella.edu': 'United States',
#  'capellauniversity.edu': 'United States',
#  'captechu.edu': 'United States',
#  'carleton.edu': 'United States',
#  'carlow.edu': 'United States',
#  'cmu.edu': 'United States',
#  'carroll.edu': 'United States',
#  'carrollu.edu': 'United States',
#  'cn.edu': 'United States',
#  'carthage.edu': 'United States',
#  'case.edu': 'United States',
#  'castleton.edu': 'United States',
#  'cua.edu': 'United States',
#  'cedarville.edu': 'United States',
#  'centenary.edu': 'United States',
#  'central.edu': 'United States',
#  'ccsu.edu': 'United States',
#  'cmc.edu': 'United States',
#  'cmich.edu': 'United States',
#  'cwu.edu': 'United States',
#  'centre.edu': 'United States',
#  'csc.edu': 'United States',
#  'champlain.edu': 'United States',
#  'chapman.edu': 'United States',
#  'chatham.edu': 'United States',
#  'chesapeake.edu': 'United States',
#  'cheyney.edu': 'United States',
#  'csopp.edu': 'United States',
#  'cbu.edu': 'United States',
#  'cts.edu': 'United States',
#  'cnu.edu': 'United States',
#  'cityu.edu': 'United States',
#  'cityuniversity.edu': 'United States',
#  'cuny.edu': 'United States',
#  'cgs.edu': 'United States',
#  'mckenna.edu': 'United States',
#  'clarion.edu': 'United States',
#  'clarke.edu': 'United States',
#  'clarkson.edu': 'United States',
#  'clarku.edu': 'United States',
#  'clayton.edu': 'United States',
#  'clemson.edu': 'United States',
#  'csuohio.edu': 'United States',
#  'clinch.edu': 'United States',
#  'coastal.edu': 'United States',
#  'cccd.edu': 'United States',
#  'coe.edu': 'United States',
#  'coker.edu': 'United States',
#  'colby.edu': 'United States',
#  'colgate.edu': 'United States',
#  'cofc.edu': 'United States',
#  'ceu.edu': 'United States',
#  'cnr.edu': 'United States',
#  'csbsju.edu': 'United States',
#  'stkate.edu': 'United States',
#  'strose.edu': 'United States',
#  'stfrancis.edu': 'United States',
#  'css.edu': 'United States',
#  'coa.edu': 'United States',
#  'holycross.edu': 'United States',
#  'wm.edu': 'United States',
#  'wooster.edu': 'United States',
#  'ccu.edu': 'United States',
#  'coloradocollege.edu': 'United States',
#  'coloradomesa.edu': 'United States',
#  'mines.edu': 'United States',
#  'colostate.edu': 'United States',
#  'coloradotech.edu': 'United States',
#  'ctuonline.edu': 'United States',
#  'colum.edu': 'United States',
#  'colsouth.edu': 'United States',
#  'cuc.edu': 'United States',
#  'columbia.edu': 'United States',
#  'ccbcmd.edu': 'United States',
#  'ccaa.edu': 'United States',
#  'cord.edu': 'United States',
#  'ccsn.edu': 'United States',
#  'csp.edu': 'United States',
#  'conncoll.edu': 'United States',
#  'ct.edu': 'United States',
#  'cooper.edu': 'United States',
#  'coppin.edu': 'United States',
#  'cornell-iowa.edu': 'United States',
#  'cornell.edu': 'United States',
#  'corning-cc.edu': 'United States',
#  'creighton.edu': 'United States',
#  'curry.edu': 'United States',
#  'daemen.edu': 'United States',
#  'dsu.edu': 'United States',
#  'dwu.edu': 'United States',
#  'dbu.edu': 'United States',
#  'dcccd.edu': 'United States',
#  'dana.edu': 'United States',
#  'dwc.edu': 'United States',
#  'dartmouth.edu': 'United States',
#  'davenport.edu': 'United States',
#  'davidson.edu': 'United States',
#  'dne.wvnet.edu': 'United States',
#  'daytonastate.edu': 'United States',
#  'dsc.edu': 'United States',
#  'deltastate.edu': 'United States',
#  'denison.edu': 'United States',
#  'depaul.edu': 'United States',
#  'depauw.edu': 'United States',
#  'devry.edu': 'United States',
#  'ddu.ac.in': 'India',
#  'dickinson.edu': 'United States',
#  'dickinsonstate.edu': 'United States',
#  'dillard.edu': 'United States',
#  'dominican.edu': 'United States',
#  'dordt.edu': 'United States',
#  'dowling.edu': 'United States',
#  'drake.edu': 'United States',
#  'drew.edu': 'United States',
#  'drexel.edu': 'United States',
#  'drury.edu': 'United States',
#  'duke.edu': 'United States',
#  'duq.edu': 'United States',
#  'earlham.edu': 'United States',
#  'ecu.edu': 'United States',
#  'ecok.edu': 'United States',
#  'easternct.edu': 'United States',
#  'eiu.edu': 'United States',
#  'eku.edu': 'United States',
#  'emu.edu': 'United States',
#  'emich.edu': 'United States',
#  'enmu.edu': 'United States',
#  'eou.edu': 'United States',
#  'ewu.edu': 'United States',
#  'esu.edu': 'United States',
#  'etsu.edu': 'United States',
#  'edgewood.edu': 'United States',
#  'edinboro.edu': 'United States',
#  'ecsu.edu': 'United States',
#  'etown.edu': 'United States',
#  'elmhurst.edu': 'United States',
#  'elon.edu': 'United States',
#  'erau.edu': 'United States',
#  'emerson.edu': 'United States',
#  'emmanuel.edu': 'United States',
#  'emory.edu': 'United States',
#  'emporia.edu': 'United States',
#  'ecc.edu': 'United States',
#  'evergreen.edu': 'United States',
#  'fdu.edu': 'United States',
#  'fairmontstate.edu': 'United States',
#  'uncfsu.edu': 'United States',
#  'ferris.edu': 'United States',
#  'fielding.edu': 'United States',
#  'fisk.edu': 'United States',
#  'fsc.edu': 'United States',
#  'famu.edu': 'United States',
#  'fau.edu': 'United States',
#  'fgcu.edu': 'United States',
#  'fit.edu': 'United States',
#  'fiu.edu': 'United States',
#  'fsu.edu': 'United States',
#  'fontbonne.edu': 'United States',
#  'fordham.edu': 'United States',
#  'fhsu.edu': 'United States',
#  'fortlewis.edu': 'United States',
#  'fountainheadcollege.edu': 'United States',
#  'fandm.edu': 'United States',
#  'fplc.edu': 'United States',
#  'franklin.edu': 'United States',
#  'frederick.edu': 'United States',
#  'fresno.edu': 'United States',
#  'friends.edu': 'United States',
#  'frostburg.edu': 'United States',
#  'fuller.edu': 'United States',
#  'furman.edu': 'United States',
#  'gallaudet.edu': 'United States',
#  'gannon.edu': 'United States',
#  'geneva.edu': 'United States',
#  'gfc.edu': 'United States',
#  'gmu.edu': 'United States',
#  'georgetown.edu': 'United States',
#  'gwu.edu': 'United States',
#  'gcsu.edu': 'United States',
#  'gatech.edu': 'United States',
#  'georgian.edu': 'United States',
#  'georgiasouthern.edu': 'United States',
#  'gsw.edu': 'United States',
#  'gsu.edu': 'United States',
#  'gettysburg.edu': 'United States',
#  'gmi.edu': 'United States',
#  'ggu.edu': 'United States',
#  'gbc.edu': 'United States',
#  'gonzaga.edu': 'United States',
#  'goshen.edu': 'United States',
#  'goucher.edu': 'United States',
#  'govst.edu': 'United States',
#  'grace.edu': 'United States',
#  'graceland.edu': 'United States',
#  'gvsu.edu': 'United States',
#  'greenleaf.edu': 'United States',
#  'grinnell.edu': 'United States',
#  'guilford.edu': 'United States',
#  'gac.edu': 'United States',
#  'hagerstowncc.edu': 'United States',
#  'hamilton.edu': 'United States',
#  'hamline.edu': 'United States',
#  'hsc.edu': 'United States',
#  'hampshire.edu': 'United States',
#  'hamptonu.edu': 'United States',
#  'hanover.edu': 'United States',
#  'harding.edu': 'United States',
#  'harford.edu': 'United States',
#  'hartwick.edu': 'United States',
#  'harvard.edu': 'United States',
#  'hmc.edu': 'United States',
#  'haskell.edu': 'United States',
#  'hastings.edu': 'United States',
#  'haverford.edu': 'United States',
#  'hpu.edu': 'United States',
#  'heidelberg.edu': 'United States',
#  'hendrix.edu': 'United States',
#  'hesston.edu': 'United States',
#  'highpoint.edu': 'United States',
#  'hillsdale.edu': 'United States',
#  'hiram.edu': 'United States',
#  'hws.edu': 'United States',
#  'hofstra.edu': 'United States',
#  'hollins.edu': 'United States',
#  'hood.edu': 'United States',
#  'hope.edu': 'United States',
#  'howardcc.edu': 'United States',
#  'howard.edu': 'United States',
#  'humboldt.edu': 'United States',
#  'hunter.cuny.edu': 'United States',
#  'huntingdon.edu': 'United States',
#  'huntington.edu': 'United States',
#  'ici.edu': 'United States',
#  'isu.edu': 'United States',
#  'ibc.edu': 'United States',
#  'iit.edu': 'United States',
#  'illinoisstate.edu': 'United States',
#  'ilstu.edu': 'United States',
#  'indianatech.edu': 'United States',
#  'indianatech.net': 'United States',
#  'indstate.edu': 'United States',
#  'iu.edu': 'United States',
#  'indiana.edu': 'United States',
#  'iub.edu': 'United States',
#  'iusb.edu': 'United States',
#  'iup.edu': 'United States',
#  'iupuc.edu': 'United States',
#  'ipfw.edu': 'United States',
#  'iupui.edu': 'United States',
#  'ius.edu': 'United States',
#  'indwes.edu': 'United States',
#  'iwp.edu': 'United States',
#  'iona.edu': 'United States',
#  'iastate.edu': 'United States',
#  'ivc.edu': 'United States',
#  'ithaca.edu': 'United States',
#  'jsums.edu': 'United States',
#  'jsu.edu': 'United States',
#  'ju.edu': 'United States',
#  'jmu.edu': 'United States',
#  'jbu.edu': 'United States',
#  'jfku.edu': 'United States',
#  'jh.edu': 'United States',
#  'jhu.edu': 'United States',
#  'jhuapl.edu': 'United States',
#  'jwu.edu': 'United States',
#  'jbc.edu': 'United States',
#  'jcsu.edu': 'United States',
#  'jones.edu': 'United States',
#  'judson.edu': 'United States',
#  'juniata.edu': 'United States',
#  'kzoo.edu': 'United States',
#  'ksu.edu': 'United States',
#  'kwu.edu': 'United States',
#  'kaplan.edu': 'United States',
#  'kean.edu': 'United States',
#  'keene.edu': 'United States',
#  'kennesaw.edu': 'United States',
#  'kent.edu': 'United States',
#  'kctcs.edu': 'United States',
#  'kenyon.edu': 'United States',
#  'kettering.edu': 'United States',
#  'kings.edu': 'United States',
#  'knox.edu': 'United States',
#  'kutztown.edu': 'United States',
#  'lafayette.edu': 'United States',
#  'lagrange.edu': 'United States',
#  'lfc.edu': 'United States',
#  'lsc.edu': 'United States',
#  'lssu.edu': 'United States',
#  'lamar.edu': 'United States',
#  'lambtoncollege.ca': 'Canada',
#  'mylambton.ca': 'Canada',
#  'langston.edu': 'United States',
#  'lasalle.edu': 'United States',
#  'lasierra.edu': 'United States',
#  'ltu.edu': 'United States',
#  'lawrence.edu': 'United States',
#  'lvc.edu': 'United States',
#  'lehigh.edu': 'United States',
#  'lemoyne.edu': 'United States',
#  'lenoircc.edu': 'United States',
#  'lrc.edu': 'United States',
#  'letu.edu': 'United States',
#  'lclark.edu': 'United States',
#  'lcsc.edu': 'United States',
#  'lewisu.edu': 'United States',
#  'liberty.edu': 'United States',
#  'lincoln.edu': 'United States',
#  'linfield.edu': 'United States',
#  'lhup.edu': 'United States',
#  'lockhaven.edu': 'United States',
#  'llu.edu': 'United States',
#  'liunet.edu': 'United States',
#  'longwood.edu': 'United States',
#  'loras.edu': 'United States',
#  'laccd.edu': 'United States',
#  'lacollege.edu': 'United States',
#  'lsu.edu': 'United States',
#  'lsua.edu': 'United States',
#  'latech.edu': 'United States',
#  'loyola.edu': 'United States',
#  'lmu.edu': 'United States',
#  'luc.edu': 'United States',
#  'luther.edu': 'United States',
#  'luthersem.edu': 'United States',
#  'lycoming.edu': 'United States',
#  'lynchburg.edu': 'United States',
#  'lyndonstate.edu': 'United States',
#  'lyon.edu': 'United States',
#  'macalester.edu': 'United States',
#  'mum.edu': 'United States',
#  'malone.edu': 'United States',
#  'manhattan.edu': 'United States',
#  'mansfield.edu': 'United States',
#  'maricopa.edu': 'United States',
#  'marietta.edu': 'United States',
#  'marist.edu': 'United States',
#  'marlboro.edu': 'United States',
#  'marquette.edu': 'United States',
#  'marshall.edu': 'United States',
#  'mbc.edu': 'United States',
#  'mmm.edu': 'United States',
#  'marymount.edu': 'United States',
#  'mwc.edu': 'United States',
#  'mit.edu': 'United States',
#  'mcdaniel.edu': 'United States',
#  'mcm.edu': 'United States',
#  'mcneese.edu': 'United States',
#  'mcg.edu': 'United States',
#  'mcw.edu': 'United States',
#  'mccc.edu': 'United States',
#  'mercer.edu': 'United States',
#  'mercymavericks.edu': 'United States',
#  'mercy.edu': 'United States',
#  'mercyhurst.edu': 'United States',
#  'meredith.edu': 'United States',
#  'messiah.edu': 'United States',
#  'mcckc.edu': 'United States',
#  'mccneb.edu': 'United States',
#  'msudenver.edu': 'United States',
#  'metrostate.edu': 'United States',
#  'miamioh.edu': 'United States',
#  'msu.edu': 'United States',
#  'mtu.edu': 'United States',
#  'manc.edu': 'United States',
#  'middlebury.edu': 'United States',
#  'mga.edu': 'United States',
#  'mtsu.edu': 'United States',
#  'mwsu.edu': 'United States',
#  'millersville.edu': 'United States',
#  'milligan.edu': 'United States',
#  'millikin.edu': 'United States',
#  'millsaps.edu': 'United States',
#  'msoe.edu': 'United States',
#  'mcad.edu': 'United States',
#  'mnsu.edu': 'United States',
#  'mnstate.edu': 'United States',
#  'minotstateu.edu': 'United States',
#  'mc.edu': 'United States',
#  'msstate.edu': 'United States',
#  'muw.edu': 'United States',
#  'mssc.edu': 'United States',
#  'mst.edu': 'United States',
#  'mwsc.edu': 'United States',
#  'molloy.edu': 'United States',
#  'monmouthcollege.edu': 'United States',
#  'monmouth.edu': 'United States',
#  'msubillings.edu': 'United States',
#  'montana.edu': 'United States',
#  'msun.edu': 'United States',
#  'mtech.edu': 'United States',
#  'montclair.edu': 'United States',
#  'montgomerycollege.edu': 'United States',
#  'montreat.edu': 'United States',
#  'moravian.edu': 'United States',
#  'morgan.edu': 'United States',
#  'mcc.edu': 'United States',
#  'mtholyoke.edu': 'United States',
#  'msj.edu': 'United States',
#  'msmc.edu': 'United States',
#  'mscfs.edu': 'United States',
#  'muc.edu': 'United States',
#  'mursuky.edu': 'United States',
#  'muskingum.edu': 'United States',
#  'nscc.edu': 'United States',
#  'ndu.edu': 'United States',
#  'nl.edu': 'United States',
#  'nrao.edu': 'United States',
#  'ntu.edu': 'United States',
#  'nu.edu': 'United States',
#  'nps.edu': 'United States',
#  'naz.edu': 'United States',
#  'nevada.edu': 'United States',
#  'newberry.edu': 'United States',
#  'newcollege.edu': 'United States',
#  'neit.edu': 'United States',
#  'nhc.edu': 'United States',
#  'njit.edu': 'United States',
#  'nmhu.edu': 'United States',
#  'nmt.edu': 'United States',
#  'nmsu.edu': 'United States',
#  'nyit.edu': 'United States',
#  'nyu.edu': 'United States',
#  'niagara.edu': 'United States',
#  'nicholls.edu': 'United States',
#  'nsu.edu': 'United States',
#  'na.edu': 'United States',
#  'northampton.edu': 'United States',
#  'ncat.edu': 'United States',
#  'nccu.edu': 'United States',
#  'ncsu.edu': 'United States',
#  'ncwc.edu': 'United States',
#  'ncbc.edu': 'United States',
#  'ndsu.edu': 'United States',
#  'nlu.edu': 'United States',
#  'nsuok.edu': 'United States',
#  'neu.edu': 'United States',
#  'northeastern.edu': 'United States',
#  'nau.edu': 'United States',
#  'niu.edu': 'United States',
#  'nku.edu': 'United States',
#  'nmu.edu': 'United States',
#  'northern.edu': 'United States',
#  'northland.edu': 'United States',
#  'npcts.edu': 'United States',
#  'nwciowa.edu': 'United States',
#  'nsula.edu': 'United States',
#  'northwestern.edu': 'United States',
#  'nwmissouri.edu': 'United States',
#  'nnc.edu': 'United States',
#  'norwich.edu': 'United States',
#  'nova.edu': 'United States',
#  'oakland.edu': 'United States',
#  'oakwood.edu': 'United States',
#  'oberlin.edu': 'United States',
#  'oxy.edu': 'United States',
#  'odc.edu': 'United States',
#  'onu.edu': 'United States',
#  'osu.edu': 'United States',
#  'ohio.edu': 'United States',
#  'ohiou.edu': 'United States',
#  'owu.edu': 'United States',
#  'okbu.edu': 'United States',
#  'okcu.edu': 'United States',
#  'okstate.edu': 'United States',
#  'odu.edu': 'United States',
#  'olivet.edu': 'United States',
#  'oru.edu': 'United States',
#  'ogi.edu': 'United States',
#  'ohsu.edu': 'United States',
#  'oit.edu': 'United States',
#  'oregonstate.edu': 'United States',
#  'otterbein.edu': 'United States',
#  'ollusa.edu': 'United States',
#  'pace.edu': 'United States',
#  'plu.edu': 'United States',
#  'puc.edu': 'United States',
#  'pacificu.edu': 'United States',
#  'pwu.com': 'United States',
#  'pbac.edu': 'United States',
#  'palmbeachstate.edu': 'United States',
#  'peace.edu': 'United States',
#  'pembroke.edu': 'United States',
#  'pct.edu': 'United States',
#  'psu.edu': 'United States',
#  'sl.psu.edu': 'United States',
#  'pcci.edu': 'United States',
#  'pensacolastate.edu': 'United States',
#  'pepperdine.edu': 'United States',
#  'peru.edu': 'United States',
#  'philau.edu': 'United States',
#  'phillips.edu': 'United States',
#  'pittstate.edu': 'United States',
#  'pitzer.edu': 'United States',
#  'platt.edu': 'United States',
#  'plymouth.edu': 'United States',
#  'poly.edu': 'United States',
#  'pupr.edu': 'Puerto Rico',
#  'pomona.edu': 'United States',
#  'pcc.edu': 'United States',
#  'pdx.edu': 'United States',
#  'pvamu.edu': 'United States',
#  'pratt.edu': 'United States',
#  'presby.edu': 'United States',
#  'prescott.edu': 'United States',
#  'princeton.edu': 'United States',
#  'providence.edu': 'United States',
#  'purdue.edu': 'United States',
#  'purduecal.edu': 'United States',
#  'pnc.edu': 'United States',
#  'quincy.edu': 'United States',
#  'quinnipiac.edu': 'United States',
#  'radford.edu': 'United States',
#  'ramapo.edu': 'United States',
#  'rmc.edu': 'United States',
#  'rmwc.edu': 'United States',
#  'reed.edu': 'United States',
#  'regent.edu': 'United States',
#  'regis.edu': 'United States',
#  'rpi.edu': 'United States',
#  'ric.edu': 'United States',
#  'rhodes.edu': 'United States',
#  'rice.edu': 'United States',
#  'stockton.edu': 'United States',
#  'rider.edu': 'United States',
#  'ripon.edu': 'United States',
#  'riv.edu': 'United States',
#  'roanoke.edu': 'United States',
#  'rmu.edu': 'United States',
#  'rit.edu': 'United States',
#  'rockefeller.edu': 'United States',
#  'rockford.edu': 'United States',
#  'rockhurst.edu': 'United States',
#  'rocky.edu': 'United States',
#  'rwu.edu': 'United States',
#  'rollins.edu': 'United States',
#  'rosary.edu': 'United States',
#  'rose-hulman.edu': 'United States',
#  'rowan.edu': 'United States',
#  'rutgers.edu': 'United States',
#  'sacredheart.edu': 'United States',
#  'sage.edu': 'United States',
#  'svsu.edu': 'United States',
#  'anselm.edu': 'United States',
#  'stcloudstate.edu': 'United States',
#  'stedwards.edu': 'United States',
#  'sfcpa.edu': 'United States',
#  'stjohns.edu': 'United States',
#  'saintjoe.edu': 'United States',
#  'sju.edu': 'United States',
#  'saintleo.edu': 'United States',
#  'slu.edu': 'United States',
#  'smcks.edu': 'United States',
#  'saintmarys.edu': 'United States',
#  'stmarys-ca.edu': 'United States',
#  'smumn.edu': 'United States',
#  'smcvt.edu': 'United States',
#  'stolaf.edu': 'United States',
#  'stvincent.edu': 'United States',
#  'sxu.edu': 'United States',
#  'salisbury.edu': 'United States',
#  'skc.edu': 'United States',
#  'samford.edu': 'United States',
#  'shsu.edu': 'United States',
#  'sdsu.edu': 'United States',
#  'sfsu.edu': 'United States',
#  'scu.edu': 'United States',
#  'slc.edu': 'United States',
#  'saic.edu': 'United States',
#  'seattlecentral.edu': 'United States',
#  'spu.edu': 'United States',
#  'seattleu.edu': 'United States',
#  'shu.edu': 'United States',
#  'sewanee.edu': 'United States',
#  'shawnee.edu': 'United States',
#  'su.edu': 'United States',
#  'ship.edu': 'United States',
#  'shorter.edu': 'United States',
#  'simmons.edu': 'United States',
#  'simons-rock.edu': 'United States',
#  'simpson.edu': 'United States',
#  'sinclair.edu': 'United States',
#  'skidmore.edu': 'United States',
#  'sru.edu': 'United States',
#  'smith.edu': 'United States',
#  'sonoma.edu': 'United States',
#  'sdsmt.edu': 'United States',
#  'sdstate.edu': 'United States',
#  'selu.edu': 'United States',
#  'semo.edu': 'United States',
#  'southern.edu': 'United States',
#  'sct.edu': 'United States',
#  'southernct.edu': 'United States',
#  'siu.edu': 'United States',
#  'siue.edu': 'United States',
#  'smu.edu': 'United States',
#  'snu.edu': 'United States',
#  'snhu.edu': 'United States',
#  'sou.edu': 'United States',
#  'subr.edu': 'United States',
#  'suu.edu': 'United States',
#  'stcl.edu': 'United States',
#  'sbuniv.edu': 'United States',
#  'swac.edu': 'United States',
#  'sagu.edu': 'United States',
#  'sckans.edu': 'United States',
#  'southwestern.edu': 'United States',
#  'smsu.edu': 'United States',
#  'swt.edu': 'United States',
#  'auc.edu': 'United States',
#  'arbor.edu': 'United States',
#  'shc.edu': 'United States',
#  'sau.edu': 'United States',
#  'sapc.edu': 'United States',
#  'stanford.edu': 'United States',
#  'albany.edu': 'United States',
#  'binghamton.edu': 'United States',
#  'buffalo.edu': 'United States',
#  'farmingdale.edu': 'United States',
#  'fredonia.edu': 'United States',
#  'oswego.edu': 'United States',
#  'plattsburgh.edu': 'United States',
#  'stonybrook.edu': 'United States',
#  'stonybrookmedicine.edu': 'United States',
#  'brockport.edu': 'United States',
#  'buffalostate.edu': 'United States',
#  'cortland.edu': 'United States',
#  'geneseo.edu': 'United States',
#  'newpaltz.edu': 'United States',
#  'potsdam.edu': 'United States',
#  'cobleskill.edu': 'United States',
#  'esf.edu': 'United States',
#  'alfredtech.edu': 'United States',
#  'sunyit.edu': 'United States',
#  'sunycentral.edu': 'United States',
#  'sbu.edu': 'United States',
#  'sfasu.edu': 'United States',
#  'stephens.edu': 'United States',
#  'stetson.edu': 'United States',
#  'stevens.edu': 'United States',
#  'stevens-tech.edu': 'United States',
#  'sjca.edu': 'United States',
#  'sjcsf.edu': 'United States',
#  'sjc.edu': 'United States',
#  'sjcme.edu': 'United States',
#  'stlawu.edu': 'United States',
#  'stlcop.edu': 'United States',
#  'stmartin.edu': 'United States',
#  'smcm.edu': 'United States',
#  'strayer.edu': 'United States',
#  'stu.edu': 'United States',
#  'suffolk.edu': 'United States',
#  'sulross.edu': 'United States',
#  'summitunivofla.edu': 'United States',
#  'susqu.edu': 'United States',
#  'swarthmore.edu': 'United States',
#  'sbc.edu': 'United States',
#  'syr.edu': 'United States',
#  'tabor.edu': 'United States',
#  'tarleton.edu': 'United States',
#  'tayloru.edu': 'United States',
#  'temple.edu': 'United States',
#  'tnstate.edu': 'United States',
#  'tntech.edu': 'United States',
#  'tccd.edu': 'United States',
#  'tamiu.edu': 'United States',
#  'tamu.edu': 'United States',
#  'tamuc.edu': 'United States',
#  'tamucc.edu': 'United States',
#  'tamuk.edu': 'United States',
#  'tcu.edu': 'United States',
#  'tsu.edu': 'United States',
#  'txstate.edu': 'United States',
#  'ttu.edu': 'United States',
#  'ttuhsc.edu': 'United States',
#  'twu.edu': 'United States',
#  'citadel.edu': 'United States',
#  'jtsa.edu': 'United States',
#  'thomas.edu': 'United States',
#  'tesc.edu': 'United States',
#  'tju.edu': 'United States',
#  'thomasmore.edu': 'United States',
#  'thunderbird.edu': 'United States',
#  'towson.edu': 'United States',
#  'transy.edu': 'United States',
#  'trenton.edu': 'United States',
#  'trine.edu': 'United States',
#  'trincoll.edu': 'United States',
#  'trinitydc.edu': 'United States',
#  'trinity.edu': 'United States',
#  'tsufl.edu': 'United States',
#  'truman.edu': 'United States',
#  'tucsonu.edu': 'United States',
#  'tufts.edu': 'United States',
#  'tulane.edu': 'United States',
#  'tuskegee.edu': 'United States',
#  'usuhs.mil': 'United States',
#  'union.edu': 'United States',
#  'tui.edu': 'United States',
#  'uu.edu': 'United States',
#  'usafa.af.mil': 'United States',
#  'usafa.edu': 'United States',
#  'usiu.edu': 'United States',
#  'usmma.edu': 'United States',
#  'usma.edu': 'United States',
#  'usna.edu': 'United States',
#  'uat.edu': 'United States',
#  'uakron.edu': 'United States',
#  'uab.edu': 'United States',
#  'uah.edu': 'United States',
#  'ua.edu': 'United States',
#  'alaska.edu': 'United States',
#  'uaa.alaska.edu': 'United States',
#  'uaf.edu': 'United States',
#  'uas.alaska.edu': 'United States',
#  'arizona.edu': 'United States',
#  'uark.edu': 'United States',
#  'uams.edu': 'United States',
#  'ualr.edu': 'United States',
#  'uamont.edu': 'United States',
#  'ubalt.edu': 'United States',
#  'bridgeport.edu': 'United States',
#  'berkeley.edu': 'United States',
#  'ucdavis.edu': 'United States',
#  'uci.edu': 'United States',
#  'ucla.edu': 'United States',
#  'ucmerced.edu': 'United States',
#  'ucr.edu': 'United States',
#  'ucsd.edu': 'United States',
#  'ucsf.edu': 'United States',
#  'ucsb.edu': 'United States',
#  'ucsc.edu': 'United States',
#  'uca.edu': 'United States',
#  'ucf.edu': 'United States',
#  'ucmo.edu': 'United States',
#  'uchaswv.edu': 'United States',
#  'uchicago.edu': 'United States',
#  'uc.edu': 'United States',
#  ...}

# %%
inst['country'] = inst.domain.map(country_uni)

# %%
inst.head()
# Out:
#                                     name        domain  \
# 0     University of California, Berkeley  berkeley.edu
# 1                     Utrecht University         uu.nl
# 2                     Utrecht University         uu.nl
# 3                     Utrecht University         uu.nl
# 4  University of California, Los Angeles      ucla.edu
#
#                      mail  authorindex               file        country
# 0        dor@berkeley.edu            0  import2016full/61  United States
# 1          s.shayan@uu.nl            1  import2016full/61    Netherlands
# 2         A.Bakker4@uu.nl            2  import2016full/61    Netherlands
# 3  M.F.vanderSchaaf@uu.nl            3  import2016full/61    Netherlands
# 4      deliema@g.ucla.edu            0  import2016full/59  United States

# %%
inst.country.value_counts()
# Out:
# United States         748
# Canada                 78
# Germany                75
# Switzerland            42
# Israel                 34
# Finland                32
# Australia              32
# Hong Kong              27
# Japan                  26
# Sweden                 22
# United Kingdom         20
# Netherlands            17
# Romania                13
# Norway                 12
# China                   7
# France                  7
# Taiwan                  6
# Turkey                  6
# Korea, Republic of      5
# Singapore               4
# Spain                   3
# India                   2
# Denmark                 2
# Ireland                 2
# Cyprus                  2
# Estonia                 1
# Iran                    1
# Brazil                  1
# Italy                   1
# South Africa            1
# Name: country, dtype: int64

# %%
inst.country.isna().sum()
# Out:
# 430

# %% [markdown]
# We can again use the email to get some additional information:
# - the final domain name indicates country

# %%
countries = open(USER_ENV+'data/country-by-domain-tld.json').read()
parsed_countries = json.loads(countries)

# %%
parsed_countries
# Out:
# [{'country': 'Afghanistan', 'tld': '.af'},
#  {'country': 'Albania', 'tld': '.al'},
#  {'country': 'Algeria', 'tld': '.dz'},
#  {'country': 'American Samoa', 'tld': '.as'},
#  {'country': 'Andorra', 'tld': '.ad'},
#  {'country': 'Angola', 'tld': '.ao'},
#  {'country': 'Anguilla', 'tld': '.ai'},
#  {'country': 'Antarctica', 'tld': '.aq'},
#  {'country': 'Antigua and Barbuda', 'tld': '.ag'},
#  {'country': 'Argentina', 'tld': '.ar'},
#  {'country': 'Armenia', 'tld': '.am'},
#  {'country': 'Aruba', 'tld': '.aw'},
#  {'country': 'Australia', 'tld': '.au'},
#  {'country': 'Austria', 'tld': '.at'},
#  {'country': 'Azerbaijan', 'tld': '.az'},
#  {'country': 'Bahamas', 'tld': '.bs'},
#  {'country': 'Bahrain', 'tld': '.bh'},
#  {'country': 'Bangladesh', 'tld': '.bd'},
#  {'country': 'Barbados', 'tld': '.bb'},
#  {'country': 'Belarus', 'tld': '.by'},
#  {'country': 'Belgium', 'tld': '.be'},
#  {'country': 'Belize', 'tld': '.bz'},
#  {'country': 'Benin', 'tld': '.bj'},
#  {'country': 'Bermuda', 'tld': '.bm'},
#  {'country': 'Bhutan', 'tld': '.bt'},
#  {'country': 'Bolivia', 'tld': '.bo'},
#  {'country': 'Bosnia and Herzegovina', 'tld': '.ba'},
#  {'country': 'Botswana', 'tld': '.bw'},
#  {'country': 'Bouvet Island', 'tld': '.bv'},
#  {'country': 'Brazil', 'tld': '.br'},
#  {'country': 'British Indian Ocean Territory', 'tld': '.io'},
#  {'country': 'Brunei', 'tld': '.bn'},
#  {'country': 'Bulgaria', 'tld': '.bg'},
#  {'country': 'Burkina Faso', 'tld': '.bf'},
#  {'country': 'Burundi', 'tld': '.bi'},
#  {'country': 'Cambodia', 'tld': '.kh'},
#  {'country': 'Cameroon', 'tld': '.cm'},
#  {'country': 'Canada', 'tld': '.ca'},
#  {'country': 'Cape Verde', 'tld': '.cv'},
#  {'country': 'Cayman Islands', 'tld': '.ky'},
#  {'country': 'Central African Republic', 'tld': '.cf'},
#  {'country': 'Chad', 'tld': '.td'},
#  {'country': 'Chile', 'tld': '.cl'},
#  {'country': 'China', 'tld': None},
#  {'country': 'Christmas Island', 'tld': '.cx'},
#  {'country': 'Cocos (Keeling) Islands', 'tld': '.cc'},
#  {'country': 'Colombia', 'tld': '.co'},
#  {'country': 'Comoros', 'tld': None},
#  {'country': 'Congo', 'tld': None},
#  {'country': 'Cook Islands', 'tld': '.ck'},
#  {'country': 'Costa Rica', 'tld': '.cr'},
#  {'country': 'Croatia', 'tld': '.hr'},
#  {'country': 'Cuba', 'tld': '.cu'},
#  {'country': 'Cyprus', 'tld': '.cy'},
#  {'country': 'Czech Republic', 'tld': '.cz'},
#  {'country': 'Denmark', 'tld': '.dk'},
#  {'country': 'Djibouti', 'tld': '.dj'},
#  {'country': 'Dominica', 'tld': '.dm'},
#  {'country': 'Dominican Republic', 'tld': '.do'},
#  {'country': 'East Timor', 'tld': '.tl'},
#  {'country': 'Ecuador', 'tld': '.ec'},
#  {'country': 'Egypt', 'tld': '.eg'},
#  {'country': 'El Salvador', 'tld': '.sv'},
#  {'country': 'England', 'tld': None},
#  {'country': 'Equatorial Guinea', 'tld': '.gq'},
#  {'country': 'Eritrea', 'tld': '.er'},
#  {'country': 'Estonia', 'tld': '.ee'},
#  {'country': 'Ethiopia', 'tld': '.et'},
#  {'country': 'Falkland Islands', 'tld': '.fk'},
#  {'country': 'Faroe Islands', 'tld': None},
#  {'country': 'Fiji Islands', 'tld': None},
#  {'country': 'Finland', 'tld': '.fi'},
#  {'country': 'France', 'tld': '.fr'},
#  {'country': 'French Guiana', 'tld': '.gf'},
#  {'country': 'French Polynesia', 'tld': '.pf'},
#  {'country': 'French Southern territories', 'tld': None},
#  {'country': 'Gabon', 'tld': '.ga'},
#  {'country': 'Gambia', 'tld': None},
#  {'country': 'Georgia', 'tld': '.ge'},
#  {'country': 'Germany', 'tld': '.de'},
#  {'country': 'Ghana', 'tld': '.gh'},
#  {'country': 'Gibraltar', 'tld': '.gi'},
#  {'country': 'Greece', 'tld': '.gr'},
#  {'country': 'Greenland', 'tld': '.gl'},
#  {'country': 'Grenada', 'tld': '.gd'},
#  {'country': 'Guadeloupe', 'tld': '.gp'},
#  {'country': 'Guam', 'tld': '.gu'},
#  {'country': 'Guatemala', 'tld': '.gt'},
#  {'country': 'Guinea', 'tld': '.gn'},
#  {'country': 'Guinea-Bissau', 'tld': None},
#  {'country': 'Guyana', 'tld': '.gy'},
#  {'country': 'Haiti', 'tld': '.ht'},
#  {'country': 'Heard Island and McDonald Islands', 'tld': '.hm'},
#  {'country': 'Holy See (Vatican City State)', 'tld': None},
#  {'country': 'Honduras', 'tld': '.hn'},
#  {'country': 'Hong Kong', 'tld': '.hk'},
#  {'country': 'Hungary', 'tld': '.hu'},
#  {'country': 'Iceland', 'tld': '.is'},
#  {'country': 'India', 'tld': '.in'},
#  {'country': 'Indonesia', 'tld': '.id'},
#  {'country': 'Iran', 'tld': '.ir'},
#  {'country': 'Iraq', 'tld': '.iq'},
#  {'country': 'Ireland', 'tld': '.ie'},
#  {'country': 'Israel', 'tld': '.il'},
#  {'country': 'Italy', 'tld': '.it'},
#  {'country': 'Ivory Coast', 'tld': '.ci'},
#  {'country': 'Jamaica', 'tld': '.jm'},
#  {'country': 'Japan', 'tld': '.jp'},
#  {'country': 'Jordan', 'tld': '.jo'},
#  {'country': 'Kazakstan', 'tld': None},
#  {'country': 'Kenya', 'tld': '.ke'},
#  {'country': 'Kiribati', 'tld': '.ki'},
#  {'country': 'Kuwait', 'tld': '.kw'},
#  {'country': 'Kyrgyzstan', 'tld': '.kg'},
#  {'country': 'Laos', 'tld': '.la'},
#  {'country': 'Latvia', 'tld': '.lv'},
#  {'country': 'Lebanon', 'tld': '.lb'},
#  {'country': 'Lesotho', 'tld': '.ls'},
#  {'country': 'Liberia', 'tld': '.lr'},
#  {'country': 'Libyan Arab Jamahiriya', 'tld': None},
#  {'country': 'Liechtenstein', 'tld': '.li'},
#  {'country': 'Lithuania', 'tld': '.lt'},
#  {'country': 'Luxembourg', 'tld': '.lu'},
#  {'country': 'Macao', 'tld': None},
#  {'country': 'Macedonia', 'tld': '.mk'},
#  {'country': 'Madagascar', 'tld': '.mg'},
#  {'country': 'Malawi', 'tld': '.mw'},
#  {'country': 'Malaysia', 'tld': '.my'},
#  {'country': 'Maldives', 'tld': '.mv'},
#  {'country': 'Mali', 'tld': '.ml'},
#  {'country': 'Malta', 'tld': '.mt'},
#  {'country': 'Marshall Islands', 'tld': '.mh'},
#  {'country': 'Martinique', 'tld': '.mq'},
#  {'country': 'Mauritania', 'tld': '.mr'},
#  {'country': 'Mauritius', 'tld': '.mu'},
#  {'country': 'Mayotte', 'tld': '.yt'},
#  {'country': 'Mexico', 'tld': '.mx'},
#  {'country': 'Micronesia, Federated States of', 'tld': None},
#  {'country': 'Moldova', 'tld': '.md'},
#  {'country': 'Monaco', 'tld': '.mc'},
#  {'country': 'Mongolia', 'tld': '.mn'},
#  {'country': 'Montserrat', 'tld': '.ms'},
#  {'country': 'Morocco', 'tld': '.ma'},
#  {'country': 'Mozambique', 'tld': '.mz'},
#  {'country': 'Myanmar', 'tld': '.mm'},
#  {'country': 'Namibia', 'tld': '.na'},
#  {'country': 'Nauru', 'tld': '.nr'},
#  {'country': 'Nepal', 'tld': '.np'},
#  {'country': 'Netherlands', 'tld': '.nl'},
#  {'country': 'Netherlands Antilles', 'tld': '.an'},
#  {'country': 'New Caledonia', 'tld': '.nc'},
#  {'country': 'New Zealand', 'tld': '.nz'},
#  {'country': 'Nicaragua', 'tld': '.ni'},
#  {'country': 'Niger', 'tld': '.ne'},
#  {'country': 'Nigeria', 'tld': '.ng'},
#  {'country': 'Niue', 'tld': '.nu'},
#  {'country': 'Norfolk Island', 'tld': '.nf'},
#  {'country': 'North Korea', 'tld': None},
#  {'country': 'Northern Ireland', 'tld': None},
#  {'country': 'Northern Mariana Islands', 'tld': '.mp'},
#  {'country': 'Norway', 'tld': '.no'},
#  {'country': 'Oman', 'tld': '.om'},
#  {'country': 'Pakistan', 'tld': '.pk'},
#  {'country': 'Palau', 'tld': None},
#  {'country': 'Palestine', 'tld': None},
#  {'country': 'Panama', 'tld': '.pa'},
#  {'country': 'Papua New Guinea', 'tld': '.pg'},
#  {'country': 'Paraguay', 'tld': '.py'},
#  {'country': 'Peru', 'tld': '.pe'},
#  {'country': 'Philippines', 'tld': '.ph'},
#  {'country': 'Pitcairn', 'tld': None},
#  {'country': 'Poland', 'tld': '.pl'},
#  {'country': 'Portugal', 'tld': '.pt'},
#  {'country': 'Puerto Rico', 'tld': '.pr'},
#  {'country': 'Qatar', 'tld': '.qa'},
#  {'country': 'Reunion', 'tld': '.re'},
#  {'country': 'Romania', 'tld': '.ro'},
#  {'country': 'Russian Federation', 'tld': None},
#  {'country': 'Rwanda', 'tld': '.rw'},
#  {'country': 'Saint Helena', 'tld': '.sh'},
#  {'country': 'Saint Kitts and Nevis', 'tld': '.kn'},
#  {'country': 'Saint Lucia', 'tld': '.lc'},
#  {'country': 'Saint Pierre and Miquelon', 'tld': None},
#  {'country': 'Saint Vincent and the Grenadines', 'tld': '.vc'},
#  {'country': 'Samoa', 'tld': '.ws'},
#  {'country': 'San Marino', 'tld': '.sm'},
#  {'country': 'Sao Tome and Principe', 'tld': '.st'},
#  {'country': 'Saudi Arabia', 'tld': '.sa'},
#  {'country': 'Scotland', 'tld': None},
#  {'country': 'Senegal', 'tld': '.sn'},
#  {'country': 'Seychelles', 'tld': '.sc'},
#  {'country': 'Sierra Leone', 'tld': '.sl'},
#  {'country': 'Singapore', 'tld': '.sg'},
#  {'country': 'Slovakia', 'tld': '.sk'},
#  {'country': 'Slovenia', 'tld': '.si'},
#  {'country': 'Solomon Islands', 'tld': '.sb'},
#  {'country': 'Somalia', 'tld': '.so'},
#  {'country': 'South Africa', 'tld': '.za'},
#  {'country': 'South Georgia and the South Sandwich Islands', 'tld': None},
#  {'country': 'South Korea', 'tld': None},
#  {'country': 'South Sudan', 'tld': '.ss'},
#  {'country': 'Spain', 'tld': None},
#  {'country': 'SriLanka', 'tld': None},
#  {'country': 'Sudan', 'tld': '.sd'},
#  {'country': 'Suriname', 'tld': '.sr'},
#  {'country': 'Svalbard and Jan Mayen', 'tld': None},
#  {'country': 'Swaziland', 'tld': '.sz'},
#  {'country': 'Sweden', 'tld': '.se'},
#  {'country': 'Switzerland', 'tld': '.ch'},
#  {'country': 'Syria', 'tld': '.sy'},
#  {'country': 'Tajikistan', 'tld': '.tj'},
#  {'country': 'Tanzania', 'tld': '.tz'},
#  {'country': 'Thailand', 'tld': '.th'},
#  {'country': 'The Democratic Republic of Congo', 'tld': None},
#  {'country': 'Togo', 'tld': '.tg'},
#  {'country': 'Tokelau', 'tld': '.tk'},
#  {'country': 'Tonga', 'tld': '.to'},
#  {'country': 'Trinidad and Tobago', 'tld': '.tt'},
#  {'country': 'Tunisia', 'tld': '.tn'},
#  {'country': 'Turkey', 'tld': '.tr'},
#  {'country': 'Turkmenistan', 'tld': '.tm'},
#  {'country': 'Turks and Caicos Islands', 'tld': '.tc'},
#  {'country': 'Tuvalu', 'tld': '.tv'},
#  {'country': 'Uganda', 'tld': '.ug'},
#  {'country': 'Ukraine', 'tld': '.ua'},
#  {'country': 'United Arab Emirates', 'tld': '.ae'},
#  {'country': 'United Kingdom', 'tld': '.gb'},
#  {'country': 'United States', 'tld': None},
#  {'country': 'United States Minor Outlying Islands', 'tld': None},
#  {'country': 'Uruguay', 'tld': '.uy'},
#  {'country': 'Uzbekistan', 'tld': '.uz'},
#  {'country': 'Vanuatu', 'tld': '.vu'},
#  {'country': 'Venezuela', 'tld': '.ve'},
#  {'country': 'Vietnam', 'tld': '.vn'},
#  {'country': 'Virgin Islands, British', 'tld': None},
#  {'country': 'Virgin Islands, U.S.', 'tld': None},
#  {'country': 'Wales', 'tld': None},
#  {'country': 'Wallis and Futuna', 'tld': '.wf'},
#  {'country': 'Western Sahara', 'tld': '.eh'},
#  {'country': 'Yemen', 'tld': '.ye'},
#  {'country': 'Yugoslavia', 'tld': None},
#  {'country': 'Zambia', 'tld': '.zm'},
#  {'country': 'Zimbabwe', 'tld': '.zw'}]

# %%
parsed_countries = { parsed['tld']: parsed['country'] for parsed in parsed_countries}
parsed_countries
# Out:
# {'.af': 'Afghanistan',
#  '.al': 'Albania',
#  '.dz': 'Algeria',
#  '.as': 'American Samoa',
#  '.ad': 'Andorra',
#  '.ao': 'Angola',
#  '.ai': 'Anguilla',
#  '.aq': 'Antarctica',
#  '.ag': 'Antigua and Barbuda',
#  '.ar': 'Argentina',
#  '.am': 'Armenia',
#  '.aw': 'Aruba',
#  '.au': 'Australia',
#  '.at': 'Austria',
#  '.az': 'Azerbaijan',
#  '.bs': 'Bahamas',
#  '.bh': 'Bahrain',
#  '.bd': 'Bangladesh',
#  '.bb': 'Barbados',
#  '.by': 'Belarus',
#  '.be': 'Belgium',
#  '.bz': 'Belize',
#  '.bj': 'Benin',
#  '.bm': 'Bermuda',
#  '.bt': 'Bhutan',
#  '.bo': 'Bolivia',
#  '.ba': 'Bosnia and Herzegovina',
#  '.bw': 'Botswana',
#  '.bv': 'Bouvet Island',
#  '.br': 'Brazil',
#  '.io': 'British Indian Ocean Territory',
#  '.bn': 'Brunei',
#  '.bg': 'Bulgaria',
#  '.bf': 'Burkina Faso',
#  '.bi': 'Burundi',
#  '.kh': 'Cambodia',
#  '.cm': 'Cameroon',
#  '.ca': 'Canada',
#  '.cv': 'Cape Verde',
#  '.ky': 'Cayman Islands',
#  '.cf': 'Central African Republic',
#  '.td': 'Chad',
#  '.cl': 'Chile',
#  None: 'Yugoslavia',
#  '.cx': 'Christmas Island',
#  '.cc': 'Cocos (Keeling) Islands',
#  '.co': 'Colombia',
#  '.ck': 'Cook Islands',
#  '.cr': 'Costa Rica',
#  '.hr': 'Croatia',
#  '.cu': 'Cuba',
#  '.cy': 'Cyprus',
#  '.cz': 'Czech Republic',
#  '.dk': 'Denmark',
#  '.dj': 'Djibouti',
#  '.dm': 'Dominica',
#  '.do': 'Dominican Republic',
#  '.tl': 'East Timor',
#  '.ec': 'Ecuador',
#  '.eg': 'Egypt',
#  '.sv': 'El Salvador',
#  '.gq': 'Equatorial Guinea',
#  '.er': 'Eritrea',
#  '.ee': 'Estonia',
#  '.et': 'Ethiopia',
#  '.fk': 'Falkland Islands',
#  '.fi': 'Finland',
#  '.fr': 'France',
#  '.gf': 'French Guiana',
#  '.pf': 'French Polynesia',
#  '.ga': 'Gabon',
#  '.ge': 'Georgia',
#  '.de': 'Germany',
#  '.gh': 'Ghana',
#  '.gi': 'Gibraltar',
#  '.gr': 'Greece',
#  '.gl': 'Greenland',
#  '.gd': 'Grenada',
#  '.gp': 'Guadeloupe',
#  '.gu': 'Guam',
#  '.gt': 'Guatemala',
#  '.gn': 'Guinea',
#  '.gy': 'Guyana',
#  '.ht': 'Haiti',
#  '.hm': 'Heard Island and McDonald Islands',
#  '.hn': 'Honduras',
#  '.hk': 'Hong Kong',
#  '.hu': 'Hungary',
#  '.is': 'Iceland',
#  '.in': 'India',
#  '.id': 'Indonesia',
#  '.ir': 'Iran',
#  '.iq': 'Iraq',
#  '.ie': 'Ireland',
#  '.il': 'Israel',
#  '.it': 'Italy',
#  '.ci': 'Ivory Coast',
#  '.jm': 'Jamaica',
#  '.jp': 'Japan',
#  '.jo': 'Jordan',
#  '.ke': 'Kenya',
#  '.ki': 'Kiribati',
#  '.kw': 'Kuwait',
#  '.kg': 'Kyrgyzstan',
#  '.la': 'Laos',
#  '.lv': 'Latvia',
#  '.lb': 'Lebanon',
#  '.ls': 'Lesotho',
#  '.lr': 'Liberia',
#  '.li': 'Liechtenstein',
#  '.lt': 'Lithuania',
#  '.lu': 'Luxembourg',
#  '.mk': 'Macedonia',
#  '.mg': 'Madagascar',
#  '.mw': 'Malawi',
#  '.my': 'Malaysia',
#  '.mv': 'Maldives',
#  '.ml': 'Mali',
#  '.mt': 'Malta',
#  '.mh': 'Marshall Islands',
#  '.mq': 'Martinique',
#  '.mr': 'Mauritania',
#  '.mu': 'Mauritius',
#  '.yt': 'Mayotte',
#  '.mx': 'Mexico',
#  '.md': 'Moldova',
#  '.mc': 'Monaco',
#  '.mn': 'Mongolia',
#  '.ms': 'Montserrat',
#  '.ma': 'Morocco',
#  '.mz': 'Mozambique',
#  '.mm': 'Myanmar',
#  '.na': 'Namibia',
#  '.nr': 'Nauru',
#  '.np': 'Nepal',
#  '.nl': 'Netherlands',
#  '.an': 'Netherlands Antilles',
#  '.nc': 'New Caledonia',
#  '.nz': 'New Zealand',
#  '.ni': 'Nicaragua',
#  '.ne': 'Niger',
#  '.ng': 'Nigeria',
#  '.nu': 'Niue',
#  '.nf': 'Norfolk Island',
#  '.mp': 'Northern Mariana Islands',
#  '.no': 'Norway',
#  '.om': 'Oman',
#  '.pk': 'Pakistan',
#  '.pa': 'Panama',
#  '.pg': 'Papua New Guinea',
#  '.py': 'Paraguay',
#  '.pe': 'Peru',
#  '.ph': 'Philippines',
#  '.pl': 'Poland',
#  '.pt': 'Portugal',
#  '.pr': 'Puerto Rico',
#  '.qa': 'Qatar',
#  '.re': 'Reunion',
#  '.ro': 'Romania',
#  '.rw': 'Rwanda',
#  '.sh': 'Saint Helena',
#  '.kn': 'Saint Kitts and Nevis',
#  '.lc': 'Saint Lucia',
#  '.vc': 'Saint Vincent and the Grenadines',
#  '.ws': 'Samoa',
#  '.sm': 'San Marino',
#  '.st': 'Sao Tome and Principe',
#  '.sa': 'Saudi Arabia',
#  '.sn': 'Senegal',
#  '.sc': 'Seychelles',
#  '.sl': 'Sierra Leone',
#  '.sg': 'Singapore',
#  '.sk': 'Slovakia',
#  '.si': 'Slovenia',
#  '.sb': 'Solomon Islands',
#  '.so': 'Somalia',
#  '.za': 'South Africa',
#  '.ss': 'South Sudan',
#  '.sd': 'Sudan',
#  '.sr': 'Suriname',
#  '.sz': 'Swaziland',
#  '.se': 'Sweden',
#  '.ch': 'Switzerland',
#  '.sy': 'Syria',
#  '.tj': 'Tajikistan',
#  '.tz': 'Tanzania',
#  '.th': 'Thailand',
#  '.tg': 'Togo',
#  '.tk': 'Tokelau',
#  '.to': 'Tonga',
#  '.tt': 'Trinidad and Tobago',
#  '.tn': 'Tunisia',
#  '.tr': 'Turkey',
#  '.tm': 'Turkmenistan',
#  '.tc': 'Turks and Caicos Islands',
#  '.tv': 'Tuvalu',
#  '.ug': 'Uganda',
#  '.ua': 'Ukraine',
#  '.ae': 'United Arab Emirates',
#  '.gb': 'United Kingdom',
#  '.uy': 'Uruguay',
#  '.uz': 'Uzbekistan',
#  '.vu': 'Vanuatu',
#  '.ve': 'Venezuela',
#  '.vn': 'Vietnam',
#  '.wf': 'Wallis and Futuna',
#  '.eh': 'Western Sahara',
#  '.ye': 'Yemen',
#  '.zm': 'Zambia',
#  '.zw': 'Zimbabwe'}

# %%
parsed_countries['.uk']= "United Kingdom"
parsed_countries['.us']  = "United States"

# %%
re.findall("(\.[a-zA-Z0-9]*$)",'ahaha.ad.uk')
# Out:
# ['.uk']

# %%
inst.loc[inst.country.isna(), 'country'] = inst[inst.country.isna()].domain.map(lambda x: re.findall("(\.[a-zA-Z0-9]*$)",x)[0]).map(parsed_countries)

# %% [markdown]
# We can give a country to a large number of authors that way, keeping in mind that 118 are gmail adresses

# %%
inst.country.isna().sum()
# Out:
# 223

# %%
inst[inst.country.isna()].domain.value_counts().head()
# Out:
# gmail.com          118
# collide.info        20
# ets.org             11
# concord.org          8
# mheducation.com      4
# Name: domain, dtype: int64

# %% [markdown]
# we can't say much about locationfrom the remaining emails, but we can use the letters before the extension as the organisation name! (unless it's gmail?)

# %%
inst[inst.country.isna()].domain.map(lambda x: re.findall("(\.[a-zA-Z0-9]*$)",x)[0]).value_counts()
# Out:
# .com      145
# .org       37
# .info      20
# .net       11
# .edu        9
# .swiss      1
# Name: domain, dtype: int64

# %% [markdown]
# Looking at the countries again:

# %%
dominant_country = inst.groupby('file').country.value_counts()

# %%
hm = pd.DataFrame(data=dominant_country)
hm.columns = ['counts']
hm.reset_index().groupby('file').max().index.is_unique
# Out:
# True

# %% [markdown]
# Plotting by dominant nation for each paper:

# %%
hm.reset_index().groupby('file').max().groupby('country').sum().sort_values('counts').plot(kind='bar')

# %%
inst.to_csv('data/Universities.csv')

# %% [markdown]
# Just one thing to check: do both data sources differentiate between Hong Kong and China? Yes

# %% [markdown]
# # Now with this data we can do some stuff:
# - Papers with authors of different origin
# - use predominant nation to remake above plot - maybe papers in the us have more coauthors -> need to find some way to normalize data
# - look at cross institution & cross country
# - maybe even look at cross continent collaboration

# %% [markdown]
# #### Tinkering around to fine more info...

# %%
i = 5
text = contents[i]
source[i]
# Out:
# 'import2016full/50'

# %%
text
# Out:
# "The Effect of Concrete Materials on Children’s Subsequent\nNumerical Explanations: Metaphorical Priming\nAndrew Manches, University of Edinburgh Moray House School of Education, a.manches@ed.ac.uk\nMihaela Dragomir, University of Edinburgh School of Informatics, m.dragomir@sms.ed.ac.uk\nAbstract: This paper contributes evidence for the claim that gestures used to support numerical\nthinking can simulate prior concrete experiences. 114 children aged 6-9 years explained a\nnumerical relationship (additive composition) three times consecutively. All children explained\nwithout materials for the 1st and 3rd explanation. For the 2nd explanation, children were randomly\nassigned to one of three conditions to use: physical objects; a number line; or no materials\n(control condition) to explain their thinking. Findings showed how using physical objects\nsignificantly influenced the particular types of gestures (e.g. splitting), hand morphology (e.g.\npinching), and words (e.g. “take”, “big”) that children used in subsequent explanations without\nmaterials. Similar (although less pronounced) priming effects were found for the number line\ncondition. The study provides support for conceptual metaphor theory (used to categorize\ngestures and language), and the potential for gesture research to address long-standing questions\nconcerning the role of concrete materials in learning.\n\nIntroduction\n\nAs well as the importance of informing everyday pedagogy, substantial research has examined if and how\nchildren’s interaction with physical materials supports learning in order to evaluate new digital forms of\ninteraction and also to better understand the relationship between action and cognition. Gesture research has\noffered a unique window into this research area by suggesting that some gestures, which are used to explain\nparticular concepts, simulate prior interactions with physical materials. The contribution of this paper is to support\nthis claim by demonstrating how asking children to explain a particular numerical relationship with physical\nmaterials significantly influences the types of gestures and language children subsequently use to explain their\nthinking without materials. By providing evidence of this internationalization of action experience, the work\nreported provides empirical support for claims surrounding the embodied nature of cognition.\n\nThe role of physical materials in learning\n\nFrom plastic blocks to a counting abacus, physical learning materials are pervasive in early learning classrooms,\nand have been designed and advocated by many educational pioneers, from Frobel to Dienes. Such use has\nattracted a wealth of research attempting to understand how, and if, they support children’s learning, particularly\nin domains such as mathematics. Unfortunately, although a relatively recent meta-analysis suggests a slight\npositive effect (Carbonneau, Marley, & Selig, 2012), there remains a lack of consensus over their benefits (McNeil\n& Jarvin, 2007), and research remains limited in its capacity to inform everyday practice.\nIt is not simply their pedagogical value however that has attracted research into physical learning\nmaterials. These objects encapsulate fundamental questions concerning the relationship between action and\ncognition. In this regard, the last two decades has witnessed increasing interest in this field, owing to two main\nreasons. The first is that new technologies are changing children’s interaction with the world, raising pertinent\nquestions about the subsequent impact on conceptual development. As well as addressing concerns that devices\n(e.g. mouse/touchscreen) limit accessibility, researchers have investigated the potential for more interactive\ndevices (e.g. tangible technology/gesture recognition devices) to leverage body based learning mechanisms\n(Manches, O’Malley, & Benford, 2010).\nThe second reason for renewed interest in physical learning materials concerns theoretical developm ...

# %%
re.findall('[\ \S]*[a-zA-Z0-9\.\-]*@[a-zA-Z0-9\.\-]*\.[a-zA-Z0-9\.\-]*(?!\S*\:\S*)', text)
# Out:
# ['Andrew Manches, University of Edinburgh Moray House School of Education, a.manches@ed.ac.uk',
#  'Mihaela Dragomir, University of Edinburgh School of Informatics, m.dragomir@sms.ed.ac.uk']

# %%
re.findall('[\s\S]*Abstract', text)
# Out:
# ['The Effect of Concrete Materials on Children’s Subsequent\nNumerical Explanations: Metaphorical Priming\nAndrew Manches, University of Edinburgh Moray House School of Education, a.manches@ed.ac.uk\nMihaela Dragomir, University of Edinburgh School of Informatics, m.dragomir@sms.ed.ac.uk\nAbstract']
